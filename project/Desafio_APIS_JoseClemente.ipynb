# %% [markdown]
# # API Mercado libre (ML_api)

# %% [markdown]
# El objetivo es poder armar un dataset con registros de inmuebles publicados en la página de mercado libre.
# Los datos de clasidicados son públicos, detallan precios, condiciones de venta/alquiler, características y zonificación del inmueble.
# Estos datos publicados por Mercado Libre (ML) en su página http://www.mercadolibre.com.ar son registrados por propietarios o agentes inmobiliarios para su libre consulta.
#
#
# Para mayor detalle inspeccionar la pág oficial de ML.

# %%
# Imports necesarios
import requests
from bs4 import BeautifulSoup
import re
from lxml import etree
import pandas as pd
import json
from pprint import pprint

# %% [markdown]
# ### API Mercado libre: _propiedades_.
#
# Vamos a hacer peticiones (GET) a la api pública de mercado libre.
#
# La búsqueda puede ser performada por query (consulta global) o category (dirigida a una categoría):
#
# Performs a search by query
#
#     GET
#         /sites/MLA/search?q=
#
# Performs a search by category
#
#     GET
#         /sites/MLA/search?category=
#
# Performs a search by seller_id
#
#     GET
#         /sites/MLA/search?seller_id=
#
# Performs a search by nickname
#
#     GET
#         /sites/MLA/search?nickname=
#
# Performs a search by special filters
#
#     GET
#         /sites/MLA/search?special_filter=
#
# Performs a search with a specific sorting method
#
#     GET
#         /sites/MLA/search?q=ipod&sort=sortId=
#
# Performs a search applying filters
#
#     GET
#         /sites/MLA/search?q=ipod&FilterID=FilterValue
#
# En el header tiene los siguientes parámetros {code} que podemos modificar
#
# Utilizaremos el siguiente métos pero inspeccionaremos el funcionamiento de otras búsquedas.
#
# url:
#
#     https://api.mercadolibre.com/sites/MLA/search?category={code}&_PublishedToday_{code}_&limit={code}&offset={code}
#
# Parámetros por categoría:
#
#     **search?category**
#     Tipo de propiedades (in la terminación luego de _ aplica a toda operación 'venta', 'alquiler', etc.)
#     casas = 'MLA1466' #_242075_242060'
#     campos = 'MLA1496_242059'
#     cocheras = 'MLA50541_267198'
#     departamentos = 'MLA1472_242062'
#     depositos_galpones = 'MLA1475_245003'
#     locales = 'MLA79242_242065'
#     oficinas = 'MLA50538_242067'
#     phs = 'MLA105179_242069'
#     quintas = 'MLA50547_242070'
#     terrenos_lotes = 'MLA1493_242071'
#
# Tiempo de publicación:
#
#     **_PublishedToday_**
#     ('YES', 'NO')
#
# paginación
#
#     **limit**
#     máx = 50
#
#     **offset**
#     número de paginación
#     0, 1 , ..., n
#
# códigos de operación
#
#     venta = 242075, alquiler = 242073, alquiler_temporal = 242074

# %% [markdown]
# # Propiedades de interes.

# %%
# Hay más, estas son las de interes por category id
property_type = {
    'departamentos': 'MLA1472',
    'casas': 'MLA1466',
    'terrenos_lotes': 'MLA1493',
    'phs': 'MLA105179',
    'locales': 'MLA79242',
    'oficinas': 'MLA50538',
    'depositos_galpones': 'MLA1475',
    'cocheras': 'MLA50541',
    'campos': 'MLA1496',
    'quintas': 'MLA50547',
}

# %% [markdown]
# # Estuctura de la respuesta a la API

# %% [markdown]
# ### Data response:
#
#     {
#       "site_id": "MLA",
#       "country_default_time_zone": "GMT-03:00",
#       "paging": {},
#       "results": [],
#       "sort": {},
#       "available_sorts": [],
#       "filters": [],
#       "available_filters": []
#     }

# %% [markdown]
# Referencia al citio y la zona.
#
#     "site_id": "MLA"
#     "country_default_time_zone": "GMT-03:00"
#
# Información de la búsqueda y paginación de la request.
#
#     "paging": {
#         "total": 219007,            # Total de registros para búsqueda.
#         "primary_results": 1000,    # Registros relevantes?
#         "offset": 0,                # Inico de búsqueda del [0 ; total/limit) devuelve "_limit_" registros
#         "limit": 50,                # Registros devueltos (máx 50) por petición
#
# Informacion requerida.
#
#     "results": []                   # len("results") = limit, siempre que no sea la última página.

# %% [markdown]
# # Inspección de prueba

# %% [markdown]
# hacemos una petición de un solo registro para conocer la estructura de la información.

# %%
# Prueba
#: params
today = 'YES'
# Parámetros mínimos para inspección de estructura.
limit = 1
offs = 0

# %%
#'https://api.mercadolibre.com/sites/MLA/search?category=¿?&_PublishedToday_¿?limit=¿?&offset=¿?'
api = f'https://api.mercadolibre.com/sites/MLA/'\
        f'search?category={property_type["departamentos"]}'\
        f'&_PublishedToday_{today}'\
        f'&limit={limit}'\
        f'&offset={offs}'

r = requests.get(api)
r.status_code
# Out:
# 200

# %% [markdown]
# ## Observando la respuesta
#
# Buscamos ver como se estructuran los datos para resgistrar solo aquellos que puedan ser de interes.

# %%
data = json.loads(r.content)

type(data), len(data), data.keys()
# Out:
# (dict,
#  8,
#  dict_keys(['site_id', 'country_default_time_zone', 'paging', 'results', 'sort', 'available_sorts', 'filters', 'available_filters']))

# %% [markdown]
# Vemos que el json de respuesta contiene 8 entradas.
# Veamos que información trae cada una de ellas.

# %%
for key in data:
    # result and avilable_filters: inspección por separado.
    if key != 'results' and key != 'available_filters':
        print(40*'-')
        print('Llave: ',key)
        pprint(data[key])
# Out:
# ----------------------------------------
# Llave:  site_id
# 'MLA'
# ----------------------------------------
# Llave:  country_default_time_zone
# 'GMT-03:00'
# ----------------------------------------
# Llave:  paging
# {'limit': 1, 'offset': 0, 'primary_results': 1000, 'total': 301069}
# ----------------------------------------
# Llave:  sort
# {'id': 'relevance', 'name': 'Más relevantes'}
# ----------------------------------------
# Llave:  available_sorts
# [{'id': 'price_asc', 'name': 'Menor precio'},
#  {'id': 'price_desc', 'name': 'Mayor precio'}]
# ----------------------------------------
# Llave:  filters
# [{'id': 'category',
#   'name': 'Categorías',
#   'type': 'text',
#   'values': [{'id': 'MLA1472',
#               'name': 'Departamentos',
#               'path_from_root': [{'id': 'MLA1459', 'name': 'Inmuebles'},
#                                  {'id': 'MLA1472', 'name': 'Departamentos'}]}]}]

# %% [markdown]
# ### 'available_filters'

# %%
type(data['available_filters']), len(data['available_filters'])
# Out:
# (list, 32)

# %% [markdown]
# aviable_filter contiene 32 variables.
#
# Diccionarios con 4 llaves. Contiene los filtros hablitados en la variable filter.
#
#     ['id', 'name', 'type', 'values']

# %%
# Inspección de 'id', 'name', 'type', 'values'.
for i, ty in enumerate (data['available_filters']):
    print(f'{i} -> {ty["id"]}: {ty["name"]}[{ty["type"]}]: {ty["values"]}', end="\n")
    print(50*'-')
# Out:
# 0 -> official_store: Tiendas oficiales[text]: [{'id': 'all', 'name': 'Todas las tiendas oficiales', 'results': 34139}, {'id': '2973', 'name': 'Tormes Propiedades', 'results': 89}, {'id': '2310', 'name': 'Salaya Romera', 'results': 1466}, {'id': '2684', 'name': 'Korn Propiedades', 'results': 551}, {'id': '2622', 'name': 'Estudio Yacoub', 'results': 2136}, {'id': '2743', 'name': 'Sistema Coldwell Banker', 'results': 1770}, {'id': '2752', 'name': 'Okeefe', 'results': 550}, {'id': '2938', 'name': 'Girard Propiedades', 'results': 428}, {'id': '2015', 'name': 'Grupo VACCARO', 'results': 62}]
# --------------------------------------------------
# 1 -> state: Ubicación[text]: [{'id': 'TUxBUENBUGw3M2E1', 'name': 'Capital Federal', 'results': 88481}, {'id': 'TUxBUEdSQWU4ZDkz', 'name': 'Bs.As. G.B.A. Norte', 'results': 34406}, {'id': 'TUxBUFNBTmU5Nzk2', 'name': 'Santa Fe', 'results': 32940}, {'id': 'TUxBUENPU2ExMmFkMw', 'name': 'Bs.As. Costa Atlántica', 'results': 32391}, {'id': 'TUxBUEdSQWVmNTVm', 'name': 'Bs.As. G.B.A. Oeste', 'results': 30684}, {'id': 'TUxBUEdSQXJlMDNm', 'name': 'Bs.As. G.B.A. Sur', 'results': 27575}, {'id': 'TUxBUFVSVXllZDVl', 'name': 'Uruguay', 'results': 26840}, {'id': 'TUxBUENPUmFkZGIw', 'name': 'Córdoba', 'results': 12873}, {'id': 'TUxBUFpPTmFpbnRl', 'name': 'Buenos Aires Interior', 'results': 5124}, {'id': 'TUxBUFLNT29iZmZm', 'name': 'Río Negro', 'results': 1647}, {'id': 'TUxBUFVTQWl1cXdlMg', 'name': 'USA', 'results': 1647}, {'id': 'TUxBUE5FVW4xMzMzNQ', 'name': 'Neuquén', 'results': 1586}, {'id': 'TUxBUE1FTmE5OWQ4', 'name': 'Mendoza', 'results': 1037}, {'id': 'TUxBUEVOVHMzNTdm', 'name': 'Entre Ríos', 'results': 1037}, {'id': 'TUxBUFRVQ244NmM3', 'name': 'Tucumán', 'results': 549}, {'id': 'TUxBUEJSQWwyMzA1', 'name': 'Brasil', 'results': 427}, {'id': 'TUxBUFNBTGFjMTJi', 'name': 'Salta', 'results': 427}, {'id': 'TUxBUE1JU3MzNjIx', 'name': 'Misiones', 'results': 305}, {'id': 'TUxBUFRJRVoxM2M5YQ', 'name': 'Tierra del Fuego', 'results': 122}, {'id': 'TUxBUEZPUmE1OTk5', 'name': 'Formosa', 'results': 61}, {'id': 'TUxBUFNBTm5lYjU4', 'name': 'San Juan', 'results': 61}, {'id': 'TUxBUFNBTnM0ZTcz', 'name': 'San Luis', 'results': 61}]
# --------------------------------------------------
# 2 -> price: Precio[range]: [{'id': '*-1.0E7', 'name': 'Hasta $ 10.000.000', 'results': 87331}, {'id': '1.0E7-2.0E7', 'name': '$10.000.000 a $20.000.000', 'results': 109343}, {'id': '2.0E7-*', 'name': 'Más de $20.000.000', 'results': 103973}]
# --------------------------------------------------
# 3 -> power_seller: Filtro por calidad de vendedores[boolean]: [{'id': 'yes', 'name': 'Mejores vendedores', 'results': 61}]
# --------------------------------------------------
# 4 -> since: Filtro por fecha de comienzo[text]: [{'id': 'today', 'name': 'Publicados hoy', 'results': 2870}]
# --------------------------------------------------
# 5 -> until: Filtro por fecha de finalización[text]: [{'id': 'today', 'name': 'Finalizan hoy', 'results': 488}]
# --------------------------------------------------
# 6 -> has_video: Filtro por publicaciones con video[boolean]: [{'id': 'yes', 'name': 'Publicaciones con video', 'results': 43038}]
# --------------------------------------------------
# 7 -> has_pictures: Filtro por publicaciones con imágenes[boolean]: [{'id': 'yes', 'name': 'Con fotos', 'results': 300220}]
# --------------------------------------------------
# 8 -> seller_type: Vendedor[text]: [{'id': 'real_estate_agency', 'name': 'Inmobiliaria', 'results': 287343}, {'id': 'private_seller', 'name': 'Dueño directo', 'results': 13304}]
# --------------------------------------------------
# 9 -> BEDROOMS: Dormitorios[range]: [{'id': '[0-0]', 'name': 'Monoambiente', 'results': 35105}, {'id': '[1-1]', 'name': '1 dormitorio', 'results': 126791}, {'id': '[2-2]', 'name': '2 dormitorios', 'results': 93338}, {'id': '[3-3]', 'name': '3 dormitorios', 'results': 36344}, {'id': '[4-*)', 'name': '4 dormitorios o más', 'results': 6962}]
# --------------------------------------------------
# 10 -> COVERED_AREA: Superficie cubierta[range]: [{'id': '(*-40m²]', 'name': '40 m² cubiertos o menos', 'results': 92158}, {'id': '²-50m²]', 'name': '40 a 50 m² cubiertos', 'results': 70800}, {'id': '²-70m²]', 'name': '50 a 70 m² cubiertos', 'results': 79001}, {'id': '²-*)', 'name': '70 m² cubiertos o más', 'results': 88618}]
# --------------------------------------------------
# 11 -> FULL_BATHROOMS: Baños[range]: [{'id': '[1-1]', 'name': '1 baño', 'results': 206795}, {'id': '[2-2]', 'name': '2 baños', 'results': 65726}, {'id': '[3-3]', 'name': '3 baños', 'results': 14278}, {'id': '[4-4]', 'name': '4 baños', 'results': 4012}, {'id': '[5-*)', 'name': '5 baños o más', 'results': 1711}]
# --------------------------------------------------
# 12 -> HAS_AIR_CONDITIONING: Otras características[boolean]: [{'id': '242085', 'name': 'Con aire acondicionado', 'results': 60770}]
# --------------------------------------------------
# 13 -> HAS_GARDEN: Otras características[boolean]: [{'id': '242085', 'name': 'Con jardín', 'results': 15281}]
# --------------------------------------------------
# 14 -> HAS_GRILL: Otras características[boolean]: [{'id': '242085', 'name': 'Con parrilla', 'results': 41241}]
# --------------------------------------------------
# 15 -> HAS_GYM: Otras características[boolean]: [{'id': '242085', 'name': 'Con gimnasio', 'results': 35931}]
# --------------------------------------------------
# 16 -> HAS_HALF_BATH: Otras características[boolean]: [{'id': '242085', 'name': 'Con toilette', 'results': 48675}]
# --------------------------------------------------
# 17 -> HAS_MULTIPURPOSE_ROOM: Otras características[boolean]: [{'id': '242085', 'name': 'Con salón de usos múltiples', 'results': 45489}]
# --------------------------------------------------
# 18 -> HAS_SWIMMING_POOL: Otras características[boolean]: [{'id': '242085', 'name': 'Con pileta', 'results': 63484}]
# --------------------------------------------------
# 19 -> IS_FINANCEABLE: Financiable[boolean]: [{'id': '242085', 'name': 'Es financiable', 'results': 8850}]
# --------------------------------------------------
# 20 -> ITEM_CONDITION: Condición[STRING]: [{'id': '2230581', 'name': 'Usado', 'results': 168209}, {'id': '2230284', 'name': 'Nuevo', 'results': 108855}]
# --------------------------------------------------
# 21 -> MAINTENANCE_FEE: Expensas[range]: [{'id': '(*-3000ARS)', 'name': '3.000 ARS o menos', 'results': 127381}, {'id': '[3000ARS-5500ARS]', 'name': '3.000 a 5.500 ARS', 'results': 24485}, {'id': '[5500ARS-10000ARS]', 'name': '5.500 a 10.000 ARS', 'results': 24839}, {'id': '[10000ARS-*)', 'name': '10.000 ARS o más', 'results': 36698}]
# --------------------------------------------------
# 22 -> OPERATION: Operación[STRING]: [{'id': '242075', 'name': 'Venta', 'results': 268391}, {'id': '242074', 'name': 'Alquiler temporal', 'results': 19411}, {'id': '242073', 'name': 'Alquiler', 'results': 8791}]
# --------------------------------------------------
# 23 -> OPERATION_SUBTYPE: Modalidad[STRING]: [{'id': '244562', 'name': 'Propiedades individuales', 'results': 267506}, {'id': '245034', 'name': 'Emprendimientos', 'results': 1416}]
# --------------------------------------------------
# 24 -> PARKING_LOTS: Cocheras[range]: [{'id': '[0-0]', 'name': 'No tiene cocheras', 'results': 197237}, {'id': '[1-1]', 'name': '1 cochera', 'results': 88264}, {'id': '[2-2]', 'name': '2 cocheras', 'results': 9440}, {'id': '[3-3]', 'name': '3 cocheras', 'results': 1003}, {'id': '[4-*)', 'name': '4 cocheras o más', 'results': 1298}]
# --------------------------------------------------
# 25 -> PROFESSIONAL_USE_ALLOWED: Otras características[boolean]: [{'id': '242085', 'name': 'Apto profesional', 'results': 30503}]
# --------------------------------------------------
# 26 -> PROPERTY_AGE: Antigüedad[range]: [{'id': '[0años-0años]', 'name': 'A estrenar', 'results': 97232}, {'id': '[1años-6años]', 'name': '1 a 6 años', 'results': 34102}, {'id': '[6años-25años]', 'name': '6 a 25 años', 'results': 40238}, {'id': '[25años-50años]', 'name': '25 a 50 años', 'results': 35282}, {'id': '[50años-*)', 'name': '50 años o más', 'results': 10030}]
# --------------------------------------------------
# 27 -> PROPERTY_TYPE: Inmueble[STRING]: [{'id': '242062', 'name': 'Departamentos', 'results': 296593}]
# --------------------------------------------------
# 28 -> ROOMS: Ambientes[range]: [{'id': '[1-1]', 'name': '1 ambiente', 'results': 47023}, {'id': '[2-2]', 'name': '2 ambientes', 'results': 107380}, {'id': '[3-3]', 'name': '3 ambientes', 'results': 90388}, {'id': '[4-*)', 'name': '4 ambientes o más', 'results': 46728}]
# --------------------------------------------------
# 29 -> SUITABLE_FOR_MORTGAGE_LOAN: Apto crédito[boolean]: [{'id': '242085', 'name': 'Es apto crédito', 'results': 36108}]
# --------------------------------------------------
# 30 -> TOTAL_AREA: Superficie total[range]: [{'id': '(*-45m²]', 'name': '45 m² totales o menos', 'results': 91037}, {'id': '²-60m²]', 'name': '45 a 60 m² totales', 'results': 73455}, {'id': '²-85m²]', 'name': '60 a 85 m² totales', 'results': 71685}, {'id': '²-*)', 'name': '85 m² totales o más', 'results': 74045}]
# --------------------------------------------------
# 31 -> WITH_VIRTUAL_TOUR: Multimedia[boolean]: [{'id': '242085', 'name': 'Tour virtual', 'results': 1003}]
# --------------------------------------------------

# %% [markdown]
# # Resumen _'_available_filter_'_
#
# Para atomizar el pedido a la API de ML se puede aplicar diferentes filtros concatenados utlizando
# * Grupo de la búsqueda:
#     /search?q=id o /search?category=id
# * Filtros concatendados:
#     &FilterID=FilterValue&FilterID=FilterValue
#
# ejemplo:
# URI:
# 'https://api.mercadolibre.com/sites/MLA/'
#
# | Búsqueda |  q_id_filter| category_id_filter|
# | --- | --- | --- |
# | propiedades = Departamento | /search?q=Departamentos | /search?category=MLA1472|
#
# URI:
# 'https://api.mercadolibre.com/sites/MLA/search?category=MLA1472'
#
# | Filtro | filter key | value | sintax |
# | --- | --- | --- | --- |
# | Antigüedad = 6 a 25 años | PROPERTY_AGE | [6años-25años] | &PROPERTY_AGE=[6años-25años] |
# | Ambientes = 3 y 4 | ROOMS | [3-4] | &ROOMS=[3-4] |
# | Ubicación = Capital Federal | state | TUxBUENBUGw3M2E1 | &state=TUxBUENBUGw3M2E1 |
#
#
# URI:
# 'https://api.mercadolibre.com/sites/MLA/search?category=MLA1472&PROPERTY_AGE=[6años-25años]&ROOMS=[3-4]&state=TUxBUENBUGw3M2E1'

# %%
# # results
len(data['results']), type(data['results'])
# Out:
# (1, list)

# %%
# # results
len(data['results'][0]), type(data['results'][0]), data['results'][0].keys()
# Out:
# (41,
#  dict,
#  dict_keys(['id', 'site_id', 'title', 'seller', 'price', 'prices', 'sale_price', 'currency_id', 'available_quantity', 'sold_quantity', 'buying_mode', 'listing_type_id', 'stop_time', 'condition', 'permalink', 'thumbnail', 'thumbnail_id', 'accepts_mercadopago', 'installments', 'address', 'promotions', 'shipping', 'seller_address', 'seller_contact', 'location', 'attributes', 'original_price', 'category_id', 'official_store_id', 'domain_id', 'catalog_product_id', 'tags', 'order_backend', 'use_thumbnail_id', 'offer_score', 'offer_share', 'match_score', 'winner_item_id', 'melicoin', 'discounts', 'inventory_id']))

# %%
# results
for i, k in enumerate (data['results'][0]):
    print(f'{i} -> {k}: {data["results"][0][k]}')#: {ty["title"]}', end="\n")
    print(50*'-')
# Out:
# 0 -> id: MLA1211661414
# --------------------------------------------------
# 1 -> site_id: MLA
# --------------------------------------------------
# 2 -> title: Almagro Alquiler 2 Ambientes Espectaculares En Piso Alto !!!!
# --------------------------------------------------
# 3 -> seller: {'id': 156220336, 'permalink': 'http://perfil.mercadolibre.com.ar/ZUKER+INMOBILIARIA', 'registration_date': '2016-02-06T01:38:15.000-04:00', 'car_dealer': False, 'real_estate_agency': True, 'tags': ['real_estate_agency', 'nsm_high', 'from_facebook', 'messages_as_seller'], 'seller_reputation': {'power_seller_status': None, 'level_id': None, 'metrics': {'cancellations': {'period': '365 days', 'rate': 0, 'value': 0}, 'claims': {'period': '365 days', 'rate': 0, 'value': 0}, 'delayed_handling_time': {'period': '365 days', 'rate': 0, 'value': 0}, 'sales': {'period': '365 days', 'completed': 0}}, 'transactions': {'canceled': 0, 'period': 'historic', 'total': 0, 'ratings': {'negative': 0, 'neutral': 0, 'positive': 0}, 'completed': 0}}}
# --------------------------------------------------
# 4 -> price: 95000
# --------------------------------------------------
# 5 -> prices: {'id': 'MLA1211661414', 'prices': [{'id': '1', 'type': 'standard', 'amount': 95000, 'regular_amount': None, 'currency_id': 'ARS', 'last_updated': '2022-10-24T18:57:12Z', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'exchange_rate_context': 'DEFAULT', 'metadata': {}}], 'presentation': {'display_currency': 'ARS'}, 'payment_method_prices': [], 'reference_prices': [], 'purchase_discounts': []}
# --------------------------------------------------
# 6 -> sale_price: None
# --------------------------------------------------
# 7 -> currency_id: ARS
# --------------------------------------------------
# 8 -> available_quantity: 1
# --------------------------------------------------
# 9 -> sold_quantity: 0
# --------------------------------------------------
# 10 -> buying_mode: classified
# --------------------------------------------------
# 11 -> listing_type_id: gold_premium
# --------------------------------------------------
# 12 -> stop_time: 2023-10-24T04:00:00.000Z
# --------------------------------------------------
# 13 -> condition: used
# --------------------------------------------------
# 14 -> permalink: https://departamento.mercadolibre.com.ar/MLA-1211661414-almagro-alquiler-2-ambientes-espectaculares-en-piso-alto--_JM
# --------------------------------------------------
# 15 -> thumbnail: http://http2.mlstatic.com/D_715757-MLA52109384816_102022-I.jpg
# --------------------------------------------------
# 16 -> thumbnail_id: 715757-MLA52109384816_102022
# --------------------------------------------------
# 17 -> accepts_mercadopago: False
# --------------------------------------------------
# 18 -> installments: None
# --------------------------------------------------
# 19 -> address: {'state_id': 'TUxBUENBUGw3M2E1', 'state_name': 'Capital Federal', 'city_id': 'TUxBQ0NBUGZlZG1sYQ', 'city_name': 'Capital Federal', 'area_code': '', 'phone1': ''}
# --------------------------------------------------
# 20 -> promotions: None
# --------------------------------------------------
# 21 -> shipping: {'free_shipping': False, 'mode': 'not_specified', 'tags': [], 'logistic_type': 'not_specified', 'store_pick_up': False}
# --------------------------------------------------
# 22 -> seller_address: {'id': '', 'comment': '', 'address_line': '', 'zip_code': '', 'country': {'id': 'AR', 'name': 'Argentina'}, 'state': {'id': 'AR-C', 'name': 'Capital Federal'}, 'city': {'id': 'TUxBQkJFTDcyNTJa', 'name': 'Belgrano'}, 'latitude': '', 'longitude': ''}
# --------------------------------------------------
# 23 -> seller_contact: {'contact': 'Zuker Servicios Inmobiliarios', 'other_info': '', 'area_code': '', 'phone': '', 'area_code2': '', 'phone2': '', 'email': '', 'webpage': ''}
# --------------------------------------------------
# 24 -> location: {'address_line': 'Av. Rivadavia al 4200', 'zip_code': '', 'subneighborhood': None, 'neighborhood': {'id': 'TUxBQkFMTTMwNTBa', 'name': 'Almagro'}, 'city': {'id': 'TUxBQ0NBUGZlZG1sYQ', 'name': 'Capital Federal'}, 'state': {'id': 'TUxBUENBUGw3M2E1', 'name': 'Capital Federal'}, 'country': {'id': 'AR', 'name': 'Argentina'}, 'latitude': -34.61366, 'longitude': -58.425385}
# --------------------------------------------------
# 25 -> attributes: [{'attribute_group_id': 'CARACTERISTICAS', 'id': 'HAS_TELEPHONE_LINE', 'value_struct': None, 'value_name': 'No', 'values': [{'id': '242084', 'name': 'No', 'struct': None, 'source': 4709975701260268}], 'attribute_group_name': 'Características adicionales', 'source': 4709975701260268, 'value_type': 'boolean', 'name': 'Línea telefónica', 'value_id': '242084'}, {'value_id': '242085', 'value_struct': None, 'attribute_group_id': 'COMOYAMEN', 'value_type': 'boolean', 'id': 'HAS_AIR_CONDITIONING', 'name': 'Aire acondicionado', 'value_name': 'Sí', 'values': [{'id': '242085', 'name': 'Sí', 'struct': None, 'source': 4709975701260268}], 'attribute_group_name': 'Comodidades y amenities', 'source': 4709975701260268}, {'attribute_group_name': 'Ficha técnica', 'value_type': 'number', 'id': 'BEDROOMS', 'name': 'Dormitorios', 'values': [{'name': '1', 'struct': None, 'source': 4709975701260268, 'id': None}], 'attribute_group_id': 'FIND', 'source': 4709975701260268, 'value_id': None, 'value_name': '1', 'value_struct': None}, {'source': 4709975701260268, 'value_type': 'number_unit', 'name': 'Superficie cubierta', 'values': [{'name': '62 m²', 'struct': {'number': 62, 'unit': 'm²'}, 'source': 4709975701260268, 'id': None}], 'attribute_group_id': 'FIND', 'value_struct': {'number': 62, 'unit': 'm²'}, 'attribute_group_name': 'Ficha técnica', 'id': 'COVERED_AREA', 'value_id': None, 'value_name': '62 m²'}, {'id': 'FULL_BATHROOMS', 'value_struct': None, 'source': 4709975701260268, 'value_type': 'number', 'name': 'Baños', 'value_id': None, 'value_name': '1', 'values': [{'struct': None, 'source': 4709975701260268, 'id': None, 'name': '1'}], 'attribute_group_id': 'FIND', 'attribute_group_name': 'Ficha técnica'}, {'value_struct': None, 'values': [{'id': None, 'name': '2', 'struct': None, 'source': 4709975701260268}], 'attribute_group_id': 'FIND', 'attribute_group_name': 'Ficha técnica', 'source': 4709975701260268, 'name': 'Ambientes', 'value_id': None, 'value_name': '2', 'value_type': 'number', 'id': 'ROOMS'}, {'value_struct': {'number': 66, 'unit': 'm²'}, 'id': 'TOTAL_AREA', 'value_id': None, 'value_name': '66 m²', 'attribute_group_name': 'Ficha técnica', 'source': 4709975701260268, 'value_type': 'number_unit', 'name': 'Superficie total', 'values': [{'id': None, 'name': '66 m²', 'struct': {'number': 66, 'unit': 'm²'}, 'source': 4709975701260268}], 'attribute_group_id': 'FIND'}, {'value_id': '242073', 'value_name': 'Alquiler', 'value_struct': None, 'values': [{'id': '242073', 'name': 'Alquiler', 'struct': None, 'source': 1}], 'attribute_group_id': 'MAIN', 'attribute_group_name': 'Principales', 'id': 'OPERATION', 'source': 1, 'value_type': 'list', 'name': 'Operación'}, {'id': 'PROPERTY_TYPE', 'name': 'Inmueble', 'attribute_group_id': 'MAIN', 'values': [{'source': 1, 'id': '242062', 'name': 'Departamento', 'struct': None}], 'attribute_group_name': 'Principales', 'source': 1, 'value_type': 'list', 'value_id': '242062', 'value_name': 'Departamento', 'value_struct': None}, {'name': 'Condición del ítem', 'value_name': 'Usado', 'attribute_group_name': 'Otros', 'source': 1, 'value_type': 'list', 'id': 'ITEM_CONDITION', 'value_id': '2230581', 'value_struct': None, 'values': [{'id': '2230581', 'name': 'Usado', 'struct': None, 'source': 1}], 'attribute_group_id': 'OTHERS'}, {'name': 'Tour virtual', 'value_name': 'No', 'values': [{'id': '242084', 'name': 'No', 'struct': None, 'source': 942334329061206}], 'attribute_group_name': 'Otros', 'source': 942334329061206, 'id': 'WITH_VIRTUAL_TOUR', 'value_id': '242084', 'value_struct': None, 'attribute_group_id': 'OTHERS', 'value_type': 'boolean'}]
# --------------------------------------------------
# 26 -> original_price: None
# --------------------------------------------------
# 27 -> category_id: MLA1473
# --------------------------------------------------
# 28 -> official_store_id: None
# --------------------------------------------------
# 29 -> domain_id: MLA-APARTMENTS_FOR_RENT
# --------------------------------------------------
# 30 -> catalog_product_id: None
# --------------------------------------------------
# 31 -> tags: ['good_quality_thumbnail', 'good_quality_picture']
# --------------------------------------------------
# 32 -> order_backend: 1
# --------------------------------------------------
# 33 -> use_thumbnail_id: True
# --------------------------------------------------
# 34 -> offer_score: None
# --------------------------------------------------
# 35 -> offer_share: None
# --------------------------------------------------
# 36 -> match_score: None
# --------------------------------------------------
# 37 -> winner_item_id: None
# --------------------------------------------------
# 38 -> melicoin: None
# --------------------------------------------------
# 39 -> discounts: None
# --------------------------------------------------
# 40 -> inventory_id: None
# --------------------------------------------------

# %%
typer = []
for ty in data['available_filters']:
    typer.append((ty['name'], type(ty), len(ty), list(ty.keys())))

typer
# Out:
# ------------------------------
# available_filters
# [{'id': 'official_store',
#   'name': 'Tiendas oficiales',
#   'type': 'text',
#   'values': [{'id': 'all',
#               'name': 'Todas las tiendas oficiales',
#               'results': 35922},
#              {'id': '2973', 'name': 'Tormes Propiedades', 'results': 148},
#              {'id': '2684', 'name': 'Korn Propiedades', 'results': 680},
#              {'id': '2622', 'name': 'Estudio Yacoub', 'results': 2448},
#              {'id': '2969',
#               'name': 'Turdo Estudio Inmobiliario',
#               'results': 188},
#              {'id': '3013', 'name': 'Gilges Inmobiliaria', 'results': 125},
#              {'id': '2695', 'name': 'Goldstein Propiedades', 'results': 611},
#              {'id': '2015', 'name': 'Grupo VACCARO', 'results': 62}]},
#  {'id': 'state',
#   'name': 'Ubicación',
#   'type': 'text',
#   'values': [{'id': 'TUxBUENBUGw3M2E1',
#               'name': 'Capital Federal',
#               'results': 86899},
#              {'id': 'TUxBUENPU2ExMmFkMw',
#               'name': 'Bs.As. Costa Atlántica',
#               'results': 34937},
#              {'id': 'TUxBUEdSQWU4ZDkz',
#               'name': 'Bs.As. G.B.A. Norte',
#               'results': 33308},
#              {'id': 'TUxBUFNBTmU5Nzk2', 'name': 'Santa Fe', 'results': 30561},
#              {'id': 'TUxBUEdSQXJlMDNm',
#               'name': 'Bs.As. G.B.A. Sur',
#               'results': 30389},
#              {'id': 'TUxBUEdSQWVmNTVm',
#               'name': 'Bs.As. G.B.A. Oeste',
#               'results': 30321},
#              {'id': 'TUxBUFVSVXllZDVl', 'name': 'Uruguay', 'results': 24339},
#              {'id': 'TUxBUENPUmFkZGIw', 'name': 'Córdoba', 'results': 14459},
#              {'id': 'TUxBUFpPTmFpbnRl',
#               'name': 'Buenos Aires Interior',
#               'results': 4575},
#              {'id': 'TUxBUE5FVW4xMzMzNQ', 'name': 'Neuquén', 'results': 2379},
#              {'id': 'TUxBUFLNT29iZmZm', 'name': 'Río Negro', 'results': 1892},
#              {'id': 'TUxBUFRVQ244NmM3', 'name': 'Tucumán', 'results': 1281},
#              {'id': 'TUxBUEVOVHMzNTdm', 'name': 'Entre Ríos', 'results': 854},
#              {'id': 'TUxBUFVTQWl1cXdlMg', 'name': 'USA', 'results': 854},
#              {'id': 'TUxBUE1FTmE5OWQ4', 'name': 'Mendoza', 'results': 671},
#              {'id': 'TUxBUFNBTGFjMTJi', 'name': 'Salta', 'results': 610},
#              {'id': 'TUxBUEJSQWwyMzA1', 'name': 'Brasil', 'results': 549},
#              {'id': 'TUxBUE1JU3MzNjIx', 'name': 'Misiones', 'results': 244},
#              {'id': 'TUxBUENIVXQxNDM1MQ', 'name': 'Chubut', 'results': 183},
#              {'id': 'TUxBUFRJRVoxM2M5YQ',
#               'name': 'Tierra del Fuego',
#               'results': 183},
#              {'id': 'TUxBUFNBTnM0ZTcz', 'name': 'San Luis', 'results': 122},
#              {'id': 'TUxBUENIQW8xMTNhOA', 'name': 'Chaco', 'results': 61},
#              {'id': 'TUxBUENPUnM5MjI0', 'name': 'Corrientes', 'results': 61},
#              {'id': 'TUxBUExBWmE1OWMy', 'name': 'La Pampa', 'results': 61},
#              {'id': 'TUxBUFNBTm5lYjU4', 'name': 'San Juan', 'results': 61}]},
#  {'id': 'price',
#   'name': 'Precio',
#   'type': 'range',
#   'values': [{'id': '*-1.0E7', 'name': 'Hasta $ 10.000.000', 'results': 86110},
#              {'id': '1.0E7-2.0E7',
#               'name': '$10.000.000 a $20.000.000',
#               'results': 107330},
#              {'id': '2.0E7-*',
#               'name': 'Más de $20.000.000',
#               'results': 106597}]}]

# %%
pd.json_normalize(data, record_path = ['results'])
# Out:
#               id site_id                                title  price  \
# 0  MLA1203712001     MLA  Depto 2 Amb Centrico!!- Ramos Mejia  38000
#
#   sale_price currency_id  available_quantity  sold_quantity buying_mode  \
# 0       None         ARS                   1              0  classified
#
#   listing_type_id  ... location.neighborhood.id location.neighborhood.name  \
# 0    gold_premium  ...         TUxBQlJBTTE3Mzla                Ramos Mejía
#
#    location.city.id location.city.name location.state.id  location.state.name  \
# 0  TUxBQ0xBTWF0YW56         La Matanza  TUxBUEdSQWVmNTVm  Bs.As. G.B.A. Oeste
#
#   location.country.id location.country.name location.latitude  \
# 0                  AR             Argentina          -34.6455
#
#   location.longitude
# 0          -58.57164
#
# [1 rows x 110 columns]

# %%
len(data['results'])
# Out:
# 2

# %%
data = requests.get(api).text

# %%
json.loads(data)
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'paging': {'total': 299418, 'primary_results': 1000, 'offset': 0, 'limit': 2},
#  'results': [{'id': 'MLA1203712001',
#    'site_id': 'MLA',
#    'title': 'Depto 2 Amb Centrico!!- Ramos Mejia',
#    'seller': {'id': 167144578,
#     'permalink': 'http://perfil.mercadolibre.com.ar/INMOBILIARIA+GILGES',
#     'registration_date': '2014-09-20T08:41:24.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': True,
#     'tags': ['real_estate_agency',
#      'brand',
#      'nsm_high',
#      'credits_profile',
#      'credits_priority_3',
#      'messages_as_seller'],
#     'seller_reputation': {'power_seller_status': None,
#      'level_id': None,
#      'metrics': {'cancellations': {'period': '365 days',
#        'rate': 0,
#        'value': 0},
#       'claims': {'period': '365 days', 'rate': 0, 'value': 0},
#       'delayed_handling_time': {'period': '365 days', 'rate': 0, 'value': 0},
#       'sales': {'period': '365 days', 'completed': 0}},
#      'transactions': {'canceled': 0,
#       'period': 'historic',
#       'total': 0,
#       'ratings': {'negative': 0, 'neutral': 0, 'positive': 0},
#       'completed': 0}}},
#    'price': 38000,
#    'prices': {'id': 'MLA1203712001',
#     'prices': [{'id': '1',
#       'type': 'standard',
#       'amount': 38000,
#       'regular_amount': None,
#       'currency_id': 'ARS',
#       'last_updated': '2022-10-20T15:10:44Z',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {}}],
#     'presentation': {'display_currency': 'ARS'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'ARS',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'classified',
#    'listing_type_id': 'gold_premium',
#    'stop_time': '2023-10-20T04:00:00.000Z',
#    'condition': 'used',
#    'permalink': 'https://departamento.mercadolibre.com.ar/MLA-1203712001-depto-2-amb-centrico-ramos-mejia-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_962003-MLA52044558919_102022-I.jpg',
#    'thumbnail_id': '962003-MLA52044558919_102022',
#    'accepts_mercadopago': False,
#    'installments': None,
#    'address': {'state_id': 'TUxBUEdSQWVmNTVm',
#     'state_name': 'Bs.As. G.B.A. Oeste',
#     'city_id': 'TUxBQ0xBTWF0YW56',
#     'city_name': 'La Matanza',
#     'area_code': '',
#     'phone1': ''},
#    'promotions': None,
#    'shipping': {'free_shipping': False,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': 'not_specified',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#     'city': {'id': None, 'name': 'Ramos Mejía'},
#     'latitude': '',
#     'longitude': ''},
#    'seller_contact': {'contact': 'Gilges Inmobiliaria',
#     'other_info': '',
#     'area_code': '',
#     'phone': '',
#     'area_code2': '',
#     'phone2': '',
#     'email': '',
#     'webpage': ''},
#    'location': {'address_line': 'Espora 91',
#     'zip_code': '',
#     'subneighborhood': None,
#     'neighborhood': {'id': 'TUxBQlJBTTE3Mzla', 'name': 'Ramos Mejía'},
#     'city': {'id': 'TUxBQ0xBTWF0YW56', 'name': 'La Matanza'},
#     'state': {'id': 'TUxBUEdSQWVmNTVm', 'name': 'Bs.As. G.B.A. Oeste'},
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'latitude': -34.6455,
#     'longitude': -58.57164},
#    'attributes': [{'id': 'HAS_TELEPHONE_LINE',
#      'name': 'Línea telefónica',
#      'value_name': 'No',
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 4709975701260268}],
#      'attribute_group_name': 'Características adicionales',
#      'value_id': '242084',
#      'value_struct': None,
#      'attribute_group_id': 'CARACTERISTICAS',
#      'source': 4709975701260268,
#      'value_type': 'boolean'},
#     {'attribute_group_id': 'COMOYAMEN',
#      'attribute_group_name': 'Comodidades y amenities',
#      'source': 4709975701260268,
#      'value_id': '242084',
#      'value_name': 'No',
#      'values': [{'name': 'No',
#        'struct': None,
#        'source': 4709975701260268,
#        'id': '242084'}],
#      'value_type': 'boolean',
#      'id': 'HAS_AIR_CONDITIONING',
#      'name': 'Aire acondicionado',
#      'value_struct': None},
#     {'name': 'Dormitorios',
#      'value_id': None,
#      'value_name': '1',
#      'attribute_group_id': 'FIND',
#      'value_type': 'number',
#      'id': 'BEDROOMS',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 4709975701260268,
#        'id': None,
#        'name': '1'}],
#      'attribute_group_name': 'Ficha técnica',
#      'source': 4709975701260268},
#     {'source': 4709975701260268,
#      'name': 'Superficie cubierta',
#      'value_id': None,
#      'values': [{'id': None,
#        'name': '35 m²',
#        'struct': {'number': 35, 'unit': 'm²'},
#        'source': 4709975701260268}],
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'id': 'COVERED_AREA',
#      'value_name': '35 m²',
#      'value_struct': {'number': 35, 'unit': 'm²'},
#      'value_type': 'number_unit'},
#     {'name': 'Baños',
#      'value_id': None,
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 4709975701260268}],
#      'source': 4709975701260268,
#      'value_type': 'number',
#      'id': 'FULL_BATHROOMS',
#      'value_name': '1',
#      'value_struct': None,
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica'},
#     {'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'value_type': 'number',
#      'id': 'ROOMS',
#      'name': 'Ambientes',
#      'value_id': None,
#      'value_name': '2',
#      'value_struct': None,
#      'values': [{'name': '2',
#        'struct': None,
#        'source': 4709975701260268,
#        'id': None}],
#      'source': 4709975701260268},
#     {'value_id': None,
#      'value_name': '35 m²',
#      'value_type': 'number_unit',
#      'values': [{'id': None,
#        'name': '35 m²',
#        'struct': {'number': 35, 'unit': 'm²'},
#        'source': 4709975701260268}],
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'source': 4709975701260268,
#      'id': 'TOTAL_AREA',
#      'name': 'Superficie total',
#      'value_struct': {'number': 35, 'unit': 'm²'}},
#     {'value_struct': None,
#      'values': [{'id': '242073',
#        'name': 'Alquiler',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'MAIN',
#      'id': 'OPERATION',
#      'name': 'Operación',
#      'value_id': '242073',
#      'value_type': 'list',
#      'value_name': 'Alquiler',
#      'attribute_group_name': 'Principales',
#      'source': 1},
#     {'id': 'PROPERTY_TYPE',
#      'name': 'Inmueble',
#      'value_id': '242062',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '242062',
#        'name': 'Departamento'}],
#      'value_name': 'Departamento',
#      'attribute_group_id': 'MAIN',
#      'attribute_group_name': 'Principales',
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'ITEM_CONDITION',
#      'value_id': '2230581',
#      'values': [{'id': '2230581',
#        'name': 'Usado',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 1,
#      'value_type': 'list',
#      'name': 'Condición del ítem',
#      'value_name': 'Usado',
#      'value_struct': None},
#     {'id': 'WITH_VIRTUAL_TOUR',
#      'value_id': '242084',
#      'value_name': 'No',
#      'value_struct': None,
#      'source': 942334329061206,
#      'value_type': 'boolean',
#      'name': 'Tour virtual',
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 942334329061206}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros'}],
#    'original_price': None,
#    'category_id': 'MLA1473',
#    'official_store_id': 3013,
#    'domain_id': 'MLA-APARTMENTS_FOR_RENT',
#    'catalog_product_id': None,
#    'tags': ['good_quality_picture', 'good_quality_thumbnail'],
#    'order_backend': 1,
#    'use_thumbnail_id': True,
#    'offer_score': None,
#    'offer_share': None,
#    'match_score': None,
#    'winner_item_id': None,
#    'melicoin': None,
#    'discounts': None,
#    'inventory_id': None},
#   {'id': 'MLA1205638836',
#    'site_id': 'MLA',
#    'title': 'Alquiler Departamento Palermo S. Ortiz Y Cervillo Parque Las Heras 2 Ambientes ',
#    'seller': {'id': 631374458,
#     'permalink': 'http://perfil.mercadolibre.com.ar/ANDREAJUDITHIMARANDREAJUDIT',
#     'registration_date': '2020-08-25T11:18:38.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': True,
#     'tags': ['real_estate_agency',
#      'nsm_low',
#      'credits_profile',
#      'messages_as_seller'],
#     'home_image_url': 'https://resources.mlstatic.com/classifieds_accounts/MLA_real_estate_agency/631374458_home.jpg',
#     'seller_reputation': {'power_seller_status': None,
#      'level_id': None,
#      'metrics': {'cancellations': {'period': '365 days',
#        'rate': 0,
#        'value': 0},
#       'claims': {'period': '365 days', 'rate': 0, 'value': 0},
#       'delayed_handling_time': {'period': '365 days', 'rate': 0, 'value': 0},
#       'sales': {'period': '365 days', 'completed': 0}},
#      'transactions': {'canceled': 0,
#       'period': 'historic',
#       'total': 0,
#       'ratings': {'negative': 0, 'neutral': 0, 'positive': 0},
#       'completed': 0}}},
#    'price': 75000,
#    'prices': {'id': 'MLA1205638836',
#     'prices': [{'id': '2',
#       'type': 'standard',
#       'amount': 75000,
#       'regular_amount': None,
#       'currency_id': 'ARS',
#       'last_updated': '2022-10-21T18:18:10Z',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {}}],
#     'presentation': {'display_currency': 'ARS'},
#     'payment_method_prices': [],
#     'reference_prices': [{'id': '3',
#       'type': 'min_standard',
#       'conditions': {'context_restrictions': ['channel_marketplace'],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 75000,
#       'currency_id': 'ARS',
#       'exchange_rate_context': 'DEFAULT',
#       'tags': [],
#       'last_updated': '2022-10-21T18:18:11Z'}],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'ARS',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'classified',
#    'listing_type_id': 'gold_premium',
#    'stop_time': '2023-10-21T04:00:00.000Z',
#    'condition': 'used',
#    'permalink': 'https://departamento.mercadolibre.com.ar/MLA-1205638836-alquiler-departamento-palermo-s-ortiz-y-cervillo-parque-las-heras-2-ambientes-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_843799-MLA52064725318_102022-I.jpg',
#    'thumbnail_id': '843799-MLA52064725318_102022',
#    'accepts_mercadopago': False,
#    'installments': None,
#    'address': {'state_id': 'TUxBUENBUGw3M2E1',
#     'state_name': 'Capital Federal',
#     'city_id': 'TUxBQ0NBUGZlZG1sYQ',
#     'city_name': 'Capital Federal',
#     'area_code': '',
#     'phone1': ''},
#    'promotions': None,
#    'shipping': {'free_shipping': False,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': 'not_specified',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#     'city': {'id': 'TUxBQkxBUzIxNTJa', 'name': 'Las Cañitas'},
#     'latitude': '',
#     'longitude': ''},
#    'seller_contact': {'contact': '',
#     'other_info': '',
#     'area_code': '',
#     'phone': '',
#     'area_code2': '',
#     'phone2': '',
#     'email': '',
#     'webpage': ''},
#    'location': {'address_line': 'Raúl Scalabrini Ortiz 3146, Buenos Aires, Argentina',
#     'zip_code': '',
#     'subneighborhood': None,
#     'neighborhood': {'id': 'TUxBQlBBTDI1MTVa', 'name': 'Palermo'},
#     'city': {'id': 'TUxBQ0NBUGZlZG1sYQ', 'name': 'Capital Federal'},
#     'state': {'id': 'TUxBUENBUGw3M2E1', 'name': 'Capital Federal'},
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'latitude': -34.58037,
#     'longitude': -58.410282},
#    'attributes': [{'value_struct': None,
#      'value_type': 'boolean',
#      'value_name': 'No',
#      'name': 'Línea telefónica',
#      'value_id': '242084',
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 7398128016960827}],
#      'attribute_group_id': 'CARACTERISTICAS',
#      'attribute_group_name': 'Características adicionales',
#      'source': 7398128016960827,
#      'id': 'HAS_TELEPHONE_LINE'},
#     {'attribute_group_id': 'COMOYAMEN',
#      'name': 'Aire acondicionado',
#      'value_id': '242084',
#      'value_name': 'No',
#      'value_struct': None,
#      'values': [{'source': 7398128016960827,
#        'id': '242084',
#        'name': 'No',
#        'struct': None}],
#      'attribute_group_name': 'Comodidades y amenities',
#      'source': 7398128016960827,
#      'id': 'HAS_AIR_CONDITIONING',
#      'value_type': 'boolean'},
#     {'attribute_group_id': 'FIND',
#      'value_type': 'number',
#      'id': 'BEDROOMS',
#      'value_id': None,
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 6316276763983939}],
#      'name': 'Dormitorios',
#      'value_name': '1',
#      'attribute_group_name': 'Ficha técnica',
#      'source': 6316276763983939},
#     {'name': 'Superficie cubierta',
#      'value_id': None,
#      'values': [{'id': None,
#        'name': '30 m²',
#        'struct': {'unit': 'm²', 'number': 30},
#        'source': 6316276763983939}],
#      'attribute_group_name': 'Ficha técnica',
#      'id': 'COVERED_AREA',
#      'value_name': '30 m²',
#      'value_struct': {'number': 30, 'unit': 'm²'},
#      'attribute_group_id': 'FIND',
#      'source': 6316276763983939,
#      'value_type': 'number_unit'},
#     {'id': 'FULL_BATHROOMS',
#      'name': 'Baños',
#      'value_id': None,
#      'attribute_group_name': 'Ficha técnica',
#      'source': 6316276763983939,
#      'value_type': 'number',
#      'value_name': '1',
#      'value_struct': None,
#      'values': [{'name': '1',
#        'struct': None,
#        'source': 6316276763983939,
#        'id': None}],
#      'attribute_group_id': 'FIND'},
#     {'attribute_group_name': 'Ficha técnica',
#      'source': 6316276763983939,
#      'value_type': 'number',
#      'value_name': '2',
#      'values': [{'id': None,
#        'name': '2',
#        'struct': None,
#        'source': 6316276763983939}],
#      'attribute_group_id': 'FIND',
#      'value_struct': None,
#      'id': 'ROOMS',
#      'name': 'Ambientes',
#      'value_id': None},
#     {'id': 'TOTAL_AREA',
#      'value_id': None,
#      'value_name': '30 m²',
#      'value_struct': {'number': 30, 'unit': 'm²'},
#      'source': 6316276763983939,
#      'name': 'Superficie total',
#      'values': [{'id': None,
#        'name': '30 m²',
#        'struct': {'number': 30, 'unit': 'm²'},
#        'source': 6316276763983939}],
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'value_type': 'number_unit'},
#     {'id': 'OPERATION',
#      'value_name': 'Alquiler',
#      'source': 1,
#      'value_type': 'list',
#      'name': 'Operación',
#      'value_id': '242073',
#      'value_struct': None,
#      'values': [{'id': '242073',
#        'name': 'Alquiler',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'MAIN',
#      'attribute_group_name': 'Principales'},
#     {'value_id': '242062',
#      'value_name': 'Departamento',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '242062',
#        'name': 'Departamento',
#        'struct': None}],
#      'attribute_group_id': 'MAIN',
#      'attribute_group_name': 'Principales',
#      'value_type': 'list',
#      'id': 'PROPERTY_TYPE',
#      'name': 'Inmueble',
#      'source': 1},
#     {'value_struct': None,
#      'attribute_group_name': 'Otros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230581',
#      'value_name': 'Usado',
#      'values': [{'source': 1,
#        'id': '2230581',
#        'name': 'Usado',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_type': 'list'},
#     {'attribute_group_id': 'OTHERS',
#      'value_type': 'boolean',
#      'source': 942334329061206,
#      'id': 'WITH_VIRTUAL_TOUR',
#      'name': 'Tour virtual',
#      'value_id': '242084',
#      'value_name': 'No',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 942334329061206}],
#      'attribute_group_name': 'Otros'}],
#    'original_price': None,
#    'category_id': 'MLA1473',
#    'official_store_id': None,
#    'domain_id': 'MLA-APARTMENTS_FOR_RENT',
#    'catalog_product_id': None,
#    'tags': ['good_quality_picture', 'good_quality_thumbnail'],
#    'order_backend': 2,
#    'use_thumbnail_id': True,
#    'offer_score': None,
#    'offer_share': None,
#    'match_score': None,
#    'winner_item_id': None,
#    'melicoin': None,
#    'discounts': None,
#    'inventory_id': None}],
#  'sort': {'id': 'relevance', 'name': 'Más relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor precio'},
#   {'id': 'price_desc', 'name': 'Mayor precio'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorías',
#    'type': 'text',
#    'values': [{'id': 'MLA1472',
#      'name': 'Departamentos',
#      'path_from_root': [{'id': 'MLA1459', 'name': 'Inmuebles'},
#       {'id': 'MLA1472', 'name': 'Departamentos'}]}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Tiendas oficiales',
#    'type': 'text',
#    'values': [{'id': 'all',
#      'name': 'Todas las tiendas oficiales',
#      'results': 33769},
#     {'id': '2973', 'name': 'Tormes Propiedades', 'results': 141},
#     {'id': '2622', 'name': 'Estudio Yacoub', 'results': 2527},
#     {'id': '2623', 'name': 'DAria', 'results': 547},
#     {'id': '2684', 'name': 'Korn Propiedades', 'results': 603},
#     {'id': '2969', 'name': 'Turdo Estudio Inmobiliario', 'results': 123},
#     {'id': '3013', 'name': 'Gilges Inmobiliaria', 'results': 3},
#     {'id': '2707', 'name': 'Tizado', 'results': 182},
#     {'id': '2695', 'name': 'Goldstein Propiedades', 'results': 481},
#     {'id': '2762', 'name': 'Castex', 'results': 301}]},
#   {'id': 'state',
#    'name': 'Ubicación',
#    'type': 'text',
#    'values': [{'id': 'TUxBUENBUGw3M2E1',
#      'name': 'Capital Federal',
#      'results': 88662},
#     {'id': 'TUxBUENPU2ExMmFkMw',
#      'name': 'Bs.As. Costa Atlántica',
#      'results': 34954},
#     {'id': 'TUxBUEdSQWU4ZDkz',
#      'name': 'Bs.As. G.B.A. Norte',
#      'results': 31869},
#     {'id': 'TUxBUFNBTmU5Nzk2', 'name': 'Santa Fe', 'results': 30600},
#     {'id': 'TUxBUEdSQWVmNTVm',
#      'name': 'Bs.As. G.B.A. Oeste',
#      'results': 30543},
#     {'id': 'TUxBUEdSQXJlMDNm', 'name': 'Bs.As. G.B.A. Sur', 'results': 30249},
#     {'id': 'TUxBUFVSVXllZDVl', 'name': 'Uruguay', 'results': 25500},
#     {'id': 'TUxBUENPUmFkZGIw', 'name': 'Córdoba', 'results': 12123},
#     {'id': 'TUxBUFpPTmFpbnRl',
#      'name': 'Buenos Aires Interior',
#      'results': 5340},
#     {'id': 'TUxBUFLNT29iZmZm', 'name': 'Río Negro', 'results': 1980},
#     {'id': 'TUxBUE5FVW4xMzMzNQ', 'name': 'Neuquén', 'results': 1860},
#     {'id': 'TUxBUFVTQWl1cXdlMg', 'name': 'USA', 'results': 1260},
#     {'id': 'TUxBUFRVQ244NmM3', 'name': 'Tucumán', 'results': 1020},
#     {'id': 'TUxBUE1FTmE5OWQ4', 'name': 'Mendoza', 'results': 660},
#     {'id': 'TUxBUEVOVHMzNTdm', 'name': 'Entre Ríos', 'results': 540},
#     {'id': 'TUxBUFNBTGFjMTJi', 'name': 'Salta', 'results': 480},
#     {'id': 'TUxBUE1JU3MzNjIx', 'name': 'Misiones', 'results': 360},
#     {'id': 'TUxBUFNBTnM0ZTcz', 'name': 'San Luis', 'results': 360},
#     {'id': 'TUxBUENIVXQxNDM1MQ', 'name': 'Chubut', 'results': 300},
#     {'id': 'TUxBUENIQW8xMTNhOA', 'name': 'Chaco', 'results': 60},
#     {'id': 'TUxBUExBWmE1OWMy', 'name': 'La Pampa', 'results': 60},
#     {'id': 'TUxBUFNBTm5lYjU4', 'name': 'San Juan', 'results': 60}]},
#   {'id': 'price',
#    'name': 'Precio',
#    'type': 'range',
#    'values': [{'id': '*-1.0E7',
#      'name': 'Hasta $ 10.000.000',
#      'results': 91480},
#     {'id': '1.0E7-2.0E7',
#      'name': '$10.000.000 a $20.000.000',
#      'results': 107008},
#     {'id': '2.0E7-*', 'name': 'Más de $20.000.000', 'results': 100892}]},
#   {'id': 'power_seller',
#    'name': 'Filtro por calidad de vendedores',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Mejores vendedores', 'results': 60}]},
#   {'id': 'since',
#    'name': 'Filtro por fecha de comienzo',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Publicados hoy', 'results': 2280}]},
#   {'id': 'until',
#    'name': 'Filtro por fecha de finalización',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Finalizan hoy', 'results': 600}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicaciones con video',
#    'type': 'boolean',
#    'values': [{'id': 'yes',
#      'name': 'Publicaciones con video',
#      'results': 41731}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicaciones con imágenes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con fotos', 'results': 298600}]},
#   {'id': 'seller_type',
#    'name': 'Vendedor',
#    'type': 'text',
#    'values': [{'id': 'real_estate_agency',
#      'name': 'Inmobiliaria',
#      'results': 285098},
#     {'id': 'private_seller', 'name': 'Dueño directo', 'results': 14282}]},
#   {'id': 'BEDROOMS',
#    'name': 'Dormitorios',
#    'type': 'range',
#    'values': [{'id': '[0-0]', 'name': 'Monoambiente', 'results': 36076},
#     {'id': '[1-1]', 'name': '1 dormitorio', 'results': 126266},
#     {'id': '[2-2]', 'name': '2 dormitorios', 'results': 88972},
#     {'id': '[3-3]', 'name': '3 dormitorios', 'results': 39208},
#     {'id': '[4-*)', 'name': '4 dormitorios o más', 'results': 6902}]},
#   {'id': 'COVERED_AREA',
#    'name': 'Superficie cubierta',
#    'type': 'range',
#    'values': [{'id': '(*-40m²]',
#      'name': '40 m² cubiertos o menos',
#      'results': 89900},
#     {'id': '²-50m²]', 'name': '40 a 50 m² cubiertos', 'results': 74008},
#     {'id': '²-70m²]', 'name': '50 a 70 m² cubiertos', 'results': 77140},
#     {'id': '²-*)', 'name': '70 m² cubiertos o más', 'results': 90480}]},
#   {'id': 'FULL_BATHROOMS',
#    'name': 'Baños',
#    'type': 'range',
#    'values': [{'id': '[1-1]', 'name': '1 baño', 'results': 203696},
#     {'id': '[2-2]', 'name': '2 baños', 'results': 64960},
#     {'id': '[3-3]', 'name': '3 baños', 'results': 16936},
#     {'id': '[4-4]', 'name': '4 baños', 'results': 3654},
#     {'id': '[5-*)', 'name': '5 baños o más', 'results': 1218}]},
#   {'id': 'HAS_AIR_CONDITIONING',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con aire acondicionado',
#      'results': 61596}]},
#   {'id': 'HAS_GARDEN',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con jardín', 'results': 15080}]},
#   {'id': 'HAS_GRILL',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con parrilla', 'results': 41934}]},
#   {'id': 'HAS_GYM',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con gimnasio', 'results': 36598}]},
#   {'id': 'HAS_HALF_BATH',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con toilette', 'results': 48836}]},
#   {'id': 'HAS_MULTIPURPOSE_ROOM',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con salón de usos múltiples',
#      'results': 44834}]},
#   {'id': 'HAS_SWIMMING_POOL',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con pileta', 'results': 61132}]},
#   {'id': 'IS_FINANCEABLE',
#    'name': 'Financiable',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Es financiable', 'results': 10904}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 167736},
#     {'id': '2230284', 'name': 'Nuevo', 'results': 106488}]},
#   {'id': 'MAINTENANCE_FEE',
#    'name': 'Expensas',
#    'type': 'range',
#    'values': [{'id': '(*-3000ARS)',
#      'name': '3.000 ARS o menos',
#      'results': 121336},
#     {'id': '[3000ARS-5500ARS]', 'name': '3.000 a 5.500 ARS', 'results': 23548},
#     {'id': '[5500ARS-10000ARS]',
#      'name': '5.500 a 10.000 ARS',
#      'results': 24824},
#     {'id': '[10000ARS-*)', 'name': '10.000 ARS o más', 'results': 38686}]},
#   {'id': 'OPERATION',
#    'name': 'Operación',
#    'type': 'STRING',
#    'values': [{'id': '242075', 'name': 'Venta', 'results': 264248},
#     {'id': '242074', 'name': 'Alquiler temporal', 'results': 19952},
#     {'id': '242073', 'name': 'Alquiler', 'results': 10904}]},
#   {'id': 'OPERATION_SUBTYPE',
#    'name': 'Modalidad',
#    'type': 'STRING',
#    'values': [{'id': '244562',
#      'name': 'Propiedades individuales',
#      'results': 263146},
#     {'id': '245034', 'name': 'Emprendimientos', 'results': 1914}]},
#   {'id': 'PARKING_LOTS',
#    'name': 'Cocheras',
#    'type': 'range',
#    'values': [{'id': '[0-0]', 'name': 'No tiene cocheras', 'results': 199752},
#     {'id': '[1-1]', 'name': '1 cochera', 'results': 84796},
#     {'id': '[2-2]', 'name': '2 cocheras', 'results': 9164},
#     {'id': '[3-3]', 'name': '3 cocheras', 'results': 1160},
#     {'id': '[4-*)', 'name': '4 cocheras o más', 'results': 1218}]},
#   {'id': 'PROFESSIONAL_USE_ALLOWED',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Apto profesional', 'results': 29870}]},
#   {'id': 'PROPERTY_AGE',
#    'name': 'Antigüedad',
#    'type': 'range',
#    'values': [{'id': '[0años-0años]', 'name': 'A estrenar', 'results': 95236},
#     {'id': '[1años-7años]', 'name': '1 a 7 años', 'results': 34394},
#     {'id': '[7años-25años]', 'name': '7 a 25 años', 'results': 36772},
#     {'id': '[25años-50años]', 'name': '25 a 50 años', 'results': 33292},
#     {'id': '[50años-*)', 'name': '50 años o más', 'results': 9454}]},
#   {'id': 'PROPERTY_TYPE',
#    'name': 'Inmueble',
#    'type': 'STRING',
#    'values': [{'id': '242062', 'name': 'Departamentos', 'results': 295104}]},
#   {'id': 'ROOMS',
#    'name': 'Ambientes',
#    'type': 'range',
#    'values': [{'id': '[1-1]', 'name': '1 ambiente', 'results': 46574},
#     {'id': '[2-2]', 'name': '2 ambientes', 'results': 110026},
#     {'id': '[3-3]', 'name': '3 ambientes', 'results': 83520},
#     {'id': '[4-*)', 'name': '4 ambientes o más', 'results': 50518}]},
#   {'id': 'SUITABLE_FOR_MORTGAGE_LOAN',
#    'name': 'Apto crédito',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Es apto crédito', 'results': 36888}]},
#   {'id': 'TOTAL_AREA',
#    'name': 'Superficie total',
#    'type': 'range',
#    'values': [{'id': '(*-45m²]',
#      'name': '45 m² totales o menos',
#      'results': 89378},
#     {'id': '²-60m²]', 'name': '45 a 60 m² totales', 'results': 74124},
#     {'id': '²-85m²]', 'name': '60 a 85 m² totales', 'results': 74414},
#     {'id': '²-*)', 'name': '85 m² totales o más', 'results': 76618}]},
#   {'id': 'WITH_VIRTUAL_TOUR',
#    'name': 'Multimedia',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Tour virtual', 'results': 696}]}]}

# %%
pd.DataFrame.from_dict(json.loads(data)['results'])
# Out:
#               id site_id                                              title  \
# 0  MLA1203712001     MLA                Depto 2 Amb Centrico!!- Ramos Mejia
# 1  MLA1205638836     MLA  Alquiler Departamento Palermo S. Ortiz Y Cervi...
#
#                                               seller  price  \
# 0  {'id': 167144578, 'permalink': 'http://perfil....  38000
# 1  {'id': 631374458, 'permalink': 'http://perfil....  75000
#
#                                               prices sale_price currency_id  \
# 0  {'id': 'MLA1203712001', 'prices': [{'id': '1',...       None         ARS
# 1  {'id': 'MLA1205638836', 'prices': [{'id': '2',...       None         ARS
#
#    available_quantity  sold_quantity  ...  \
# 0                   1              0  ...
# 1                   1              0  ...
#
#                                              tags order_backend  \
# 0  [good_quality_picture, good_quality_thumbnail]             1
# 1  [good_quality_picture, good_quality_thumbnail]             2
#
#   use_thumbnail_id offer_score offer_share match_score winner_item_id  \
# 0             True        None        None        None           None
# 1             True        None        None        None           None
#
#    melicoin discounts inventory_id
# 0      None      None         None
# 1      None      None         None
#
# [2 rows x 41 columns]

# %%
pd.json_normalize(data, record_path = ['results'])
# Out:
#               id site_id                                title  price  \
# 0  MLA1203712001     MLA  Depto 2 Amb Centrico!!- Ramos Mejia  38000
#
#   sale_price currency_id  available_quantity  sold_quantity buying_mode  \
# 0       None         ARS                   1              0  classified
#
#   listing_type_id  ... location.neighborhood.id location.neighborhood.name  \
# 0    gold_premium  ...         TUxBQlJBTTE3Mzla                Ramos Mejía
#
#    location.city.id location.city.name location.state.id  location.state.name  \
# 0  TUxBQ0xBTWF0YW56         La Matanza  TUxBUEdSQWVmNTVm  Bs.As. G.B.A. Oeste
#
#   location.country.id location.country.name location.latitude  \
# 0                  AR             Argentina          -34.6455
#
#   location.longitude
# 0          -58.57164
#
# [1 rows x 110 columns]

# %%
for offset in range(0,paginators):
    url = self.ml_url + self.objeto.mercadolibre_id + '&_PublishedToday_YES&limit=50&offset=' + str(offset*50)
    jsdata = self.request_get(url)
    if(jsdata is not None): self.items = self.items + jsdata['results']
self.adapt()
