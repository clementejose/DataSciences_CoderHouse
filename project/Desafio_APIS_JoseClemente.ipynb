# %% [markdown]
# # API Mercado libre (ML_api)

# %% [markdown]
# El objetivo es poder armar un dataset con registros de inmuebles publicados en la página de mercado libre.
# Los datos de clasidicados son públicos, detallan precios, condiciones de venta/alquiler, características y zonificación del inmueble.
# Estos datos publicados por Mercado Libre (ML) en su página http://www.mercadolibre.com.ar son registrados por propietarios o agentes inmobiliarios para su libre consulta.
#
#
# Para mayor detalle inspeccionar la pág oficial de ML.

# %%
# Imports necesarios
import requests
from bs4 import BeautifulSoup
import re
from lxml import etree
import pandas as pd
import json
from pprint import pprint

# %% [markdown]
# ### API Mercado libre: _propiedades_.
#
# Vamos a hacer peticiones (GET) a la api pública de mercado libre.
#
# La búsqueda puede ser performada por query (consulta global) o category (dirigida a una categoría):
#
# Performs a search by query
#
#     GET
#         /sites/MLA/search?q=
#
# Performs a search by category
#
#     GET
#         /sites/MLA/search?category=
#
# Performs a search by seller_id
#
#     GET
#         /sites/MLA/search?seller_id=
#
# Performs a search by nickname
#
#     GET
#         /sites/MLA/search?nickname=
#
# Performs a search by special filters
#
#     GET
#         /sites/MLA/search?special_filter=
#
# Performs a search with a specific sorting method
#
#     GET
#         /sites/MLA/search?q=ipod&sort=sortId=
#
# Performs a search applying filters
#
#     GET
#         /sites/MLA/search?q=ipod&FilterID=FilterValue
#
# En el header tiene los siguientes parámetros {code} que podemos modificar
#
# Utilizaremos el siguiente métos pero inspeccionaremos el funcionamiento de otras búsquedas.
#
# url:
#
#     https://api.mercadolibre.com/sites/MLA/search?category={code}&_PublishedToday_{code}_&limit={code}&offset={code}
#
# Parámetros por categoría:
#
#     **search?category**
#     Tipo de propiedades (in la terminación luego de _ aplica a toda operación 'venta', 'alquiler', etc.)
#     casas = 'MLA1466' #_242075_242060'
#     campos = 'MLA1496_242059'
#     cocheras = 'MLA50541_267198'
#     departamentos = 'MLA1472_242062'
#     depositos_galpones = 'MLA1475_245003'
#     locales = 'MLA79242_242065'
#     oficinas = 'MLA50538_242067'
#     phs = 'MLA105179_242069'
#     quintas = 'MLA50547_242070'
#     terrenos_lotes = 'MLA1493_242071'
#
# Tiempo de publicación:
#
#     **_PublishedToday_**
#     ('YES', 'NO')
#
# paginación
#
#     **limit**
#     máx = 50
#
#     **offset**
#     número de paginación
#     0, 1 , ..., n
#
# códigos de operación
#
#     venta = 242075, alquiler = 242073, alquiler_temporal = 242074

# %% [markdown]
# # Propiedades de interes.

# %%
# Hay más, estas son las de interes por category id
property_type = {
    'departamentos': 'MLA1472',
    'casas': 'MLA1466',
    'terrenos_lotes': 'MLA1493',
    'phs': 'MLA105179',
    'locales': 'MLA79242',
    'oficinas': 'MLA50538',
    'depositos_galpones': 'MLA1475',
    'cocheras': 'MLA50541',
    'campos': 'MLA1496',
    'quintas': 'MLA50547',
}

# %% [markdown]
# # Estuctura de la respuesta a la API

# %% [markdown]
# ### Data response:
#
#     {
#       "site_id": "MLA",
#       "country_default_time_zone": "GMT-03:00",
#       "paging": {},
#       "results": [],
#       "sort": {},
#       "available_sorts": [],
#       "filters": [],
#       "available_filters": []
#     }

# %% [markdown]
# Referencia al citio y la zona.
#
#     "site_id": "MLA"
#     "country_default_time_zone": "GMT-03:00"
#
# Información de la búsqueda y paginación de la request.
#
#     "paging": {
#         "total": 219007,            # Total de registros para búsqueda.
#         "primary_results": 1000,    # Registros relevantes?
#         "offset": 0,                # Inico de búsqueda del [0 ; total/limit) devuelve "_limit_" registros
#         "limit": 50,                # Registros devueltos (máx 50) por petición
#
# Informacion requerida.
#
#     "results": []                   # len("results") = limit, siempre que no sea la última página.

# %% [markdown]
# # Inspección de prueba

# %% [markdown]
# hacemos una petición de un solo registro para conocer la estructura de la información.

# %%
# Prueba
#: params
today = 'YES'
# Parámetros mínimos para inspección de estructura.
limit = 3
offs = 0

# %%
# url = "https://api.mercadolibre.com/sites/MLA/search?q=Departamentos&date_from=2021-01-01&date_to=2022-02-01&limit=3"
# r = requests.get(url)
# r.status_code

# %%
#'https://api.mercadolibre.com/sites/MLA/search?category=¿?&_PublishedToday_¿?limit=¿?&offset=¿?' # f'search?q=Departamentos'\
api = f'https://api.mercadolibre.com/sites/MLA/'\
        f'search?category={property_type["departamentos"]}'\
        f'&_PublishedToday_{today}'\
        f'&limit={limit}'\
        f'&offset={offs}'

r = requests.get(api)
r.status_code
# Out:
# 200

# %% [markdown]
# ## Observando la respuesta
#
# Buscamos ver como se estructuran los datos para resgistrar solo aquellos que puedan ser de interes.

# %%
data = json.loads(r.content)

type(data), len(data), data.keys()
# Out:
# (dict,
#  8,
#  dict_keys(['site_id', 'country_default_time_zone', 'paging', 'results', 'sort', 'available_sorts', 'filters', 'available_filters']))

# %% [markdown]
# Vemos que el json de respuesta contiene 8 entradas.
# Veamos que información trae cada una de ellas.

# %%
for i, key in enumerate(data):
    # result and avilable_filters: inspección por separado.
    if key != 'results' and key != 'available_filters':
        print(i ,'-> key: ',key)
        pprint(data[key])
        print(40*'-')
# Out:
# 0 -> key:  site_id
# 'MLA'
# ----------------------------------------
# 1 -> key:  country_default_time_zone
# 'GMT-03:00'
# ----------------------------------------
# 2 -> key:  paging
# {'limit': 3, 'offset': 0, 'primary_results': 1000, 'total': 299136}
# ----------------------------------------
# 4 -> key:  sort
# {'id': 'relevance', 'name': 'Más relevantes'}
# ----------------------------------------
# 5 -> key:  available_sorts
# [{'id': 'price_asc', 'name': 'Menor precio'},
#  {'id': 'price_desc', 'name': 'Mayor precio'}]
# ----------------------------------------
# 6 -> key:  filters
# [{'id': 'category',
#   'name': 'Categorías',
#   'type': 'text',
#   'values': [{'id': 'MLA1472',
#               'name': 'Departamentos',
#               'path_from_root': [{'id': 'MLA1459', 'name': 'Inmuebles'},
#                                  {'id': 'MLA1472', 'name': 'Departamentos'}]}]}]
# ----------------------------------------

# %% [markdown]
# ## 'available_filters'

# %%
type(data['available_filters']), len(data['available_filters'])
# Out:
# (list, 32)

# %% [markdown]
# aviable_filter contiene 32 variables.
#
# Diccionarios con 4 llaves. Contiene los filtros hablitados en la variable filter.
#
#     ['id', 'name', 'type', 'values']

# %%
# Inspección de 'id', 'name', 'type', 'values'.
for i, ty in enumerate (data['available_filters']):
    print(f'{i} -> id = {ty["id"]}:\n{ty["name"]}[{ty["type"]}]: {ty["values"]}', end="\n")
    print(50*'-')
# Out:
# 0 -> id = official_store:
# Tiendas oficiales[text]: [{'id': 'all', 'name': 'Todas las tiendas oficiales', 'results': 38387}, {'id': '2973', 'name': 'Tormes Propiedades', 'results': 90}, {'id': '2622', 'name': 'Estudio Yacoub', 'results': 2888}, {'id': '2695', 'name': 'Goldstein Propiedades', 'results': 662}, {'id': '2743', 'name': 'Sistema Coldwell Banker', 'results': 1921}, {'id': '2636', 'name': 'Toribio Achaval', 'results': 1381}, {'id': '2980', 'name': 'KRELL BROKERS', 'results': 361}, {'id': '3035', 'name': 'DUIT Propiedades', 'results': 241}, {'id': '2900', 'name': 'Oppel Inmobiliaria', 'results': 121}, {'id': '2969', 'name': 'Turdo Estudio Inmobiliario', 'results': 1}]
# --------------------------------------------------
# 1 -> id = state:
# Ubicación[text]: [{'id': 'TUxBUENBUGw3M2E1', 'name': 'Capital Federal', 'results': 90030}, {'id': 'TUxBUEdSQWU4ZDkz', 'name': 'Bs.As. G.B.A. Norte', 'results': 36001}, {'id': 'TUxBUENPU2ExMmFkMw', 'name': 'Bs.As. Costa Atlántica', 'results': 32511}, {'id': 'TUxBUFNBTmU5Nzk2', 'name': 'Santa Fe', 'results': 32400}, {'id': 'TUxBUEdSQXJlMDNm', 'name': 'Bs.As. G.B.A. Sur', 'results': 31093}, {'id': 'TUxBUEdSQWVmNTVm', 'name': 'Bs.As. G.B.A. Oeste', 'results': 30723}, {'id': 'TUxBUFVSVXllZDVl', 'name': 'Uruguay', 'results': 21240}, {'id': 'TUxBUENPUmFkZGIw', 'name': 'Córdoba', 'results': 12182}, {'id': 'TUxBUFpPTmFpbnRl', 'name': 'Buenos Aires Interior', 'results': 4020}, {'id': 'TUxBUE5FVW4xMzMzNQ', 'name': 'Neuquén', 'results': 1800}, {'id': 'TUxBUFLNT29iZmZm', 'name': 'Río Negro', 'results': 1320}, {'id': 'TUxBUFRVQ244NmM3', 'name': 'Tucumán', 'results': 1260}, {'id': 'TUxBUE1FTmE5OWQ4', 'name': 'Mendoza', 'results': 660}, {'id': 'TUxBUEVOVHMzNTdm', 'name': 'Entre Ríos', 'results': 540}, {'id': 'TUxBUENIVXQxNDM1MQ', 'name': 'Chubut', 'results': 420}, {'id': 'TUxBUFNBTGFjMTJi', 'name': 'Salta', 'results': 360}, {'id': 'TUxBUEJSQWwyMzA1', 'name': 'Brasil', 'results': 180}, {'id': 'TUxBUENPUnM5MjI0', 'name': 'Corrientes', 'results': 180}, {'id': 'TUxBUFNBTm5lYjU4', 'name': 'San Juan', 'results': 120}, {'id': 'TUxBUE1JU3MzNjIx', 'name': 'Misiones', 'results': 60}, {'id': 'TUxBUENIQW8xMTNhOA', 'name': 'Chaco', 'results': 60}, {'id': 'TUxBUExBWmEyNzY0', 'name': 'La Rioja', 'results': 60}, {'id': 'TUxBUFNBTnM0ZTcz', 'name': 'San Luis', 'results': 60}, {'id': 'TUxBUFNBTno3ZmY5', 'name': 'Santa Cruz', 'results': 60}, {'id': 'TUxBUFRJRVoxM2M5YQ', 'name': 'Tierra del Fuego', 'results': 60}]
# --------------------------------------------------
# 2 -> id = price:
# Precio[range]: [{'id': '*-1.0E7', 'name': 'Hasta $ 10.000.000', 'results': 86633}, {'id': '1.0E7-2.0E7', 'name': '$10.000.000 a $20.000.000', 'results': 104725}, {'id': '2.0E7-*', 'name': 'Más de $20.000.000', 'results': 107722}]
# --------------------------------------------------
# 3 -> id = power_seller:
# Filtro por calidad de vendedores[boolean]: [{'id': 'yes', 'name': 'Mejores vendedores', 'results': 180}]
# --------------------------------------------------
# 4 -> id = since:
# Filtro por fecha de comienzo[text]: [{'id': 'today', 'name': 'Publicados hoy', 'results': 600}]
# --------------------------------------------------
# 5 -> id = until:
# Filtro por fecha de finalización[text]: [{'id': 'today', 'name': 'Finalizan hoy', 'results': 600}]
# --------------------------------------------------
# 6 -> id = has_video:
# Filtro por publicaciones con video[boolean]: [{'id': 'yes', 'name': 'Publicaciones con video', 'results': 38008}]
# --------------------------------------------------
# 7 -> id = has_pictures:
# Filtro por publicaciones con imágenes[boolean]: [{'id': 'yes', 'name': 'Con fotos', 'results': 298780}]
# --------------------------------------------------
# 8 -> id = seller_type:
# Vendedor[text]: [{'id': 'real_estate_agency', 'name': 'Inmobiliaria', 'results': 285995}, {'id': 'private_seller', 'name': 'Dueño directo', 'results': 13085}]
# --------------------------------------------------
# 9 -> id = BEDROOMS:
# Dormitorios[range]: [{'id': '[0-0]', 'name': 'Monoambiente', 'results': 38048}, {'id': '[1-1]', 'name': '1 dormitorio', 'results': 123656}, {'id': '[2-2]', 'name': '2 dormitorios', 'results': 88856}, {'id': '[3-3]', 'name': '3 dormitorios', 'results': 39324}, {'id': '[4-*)', 'name': '4 dormitorios o más', 'results': 6844}]
# --------------------------------------------------
# 10 -> id = COVERED_AREA:
# Superficie cubierta[range]: [{'id': '(*-40m²]', 'name': '40 m² cubiertos o menos', 'results': 91292}, {'id': '²-50m²]', 'name': '40 a 50 m² cubiertos', 'results': 69020}, {'id': '²-70m²]', 'name': '50 a 70 m² cubiertos', 'results': 74994}, {'id': '²-*)', 'name': '70 m² cubiertos o más', 'results': 91582}]
# --------------------------------------------------
# 11 -> id = FULL_BATHROOMS:
# Baños[range]: [{'id': '[1-1]', 'name': '1 baño', 'results': 202420}, {'id': '[2-2]', 'name': '2 baños', 'results': 66004}, {'id': '[3-3]', 'name': '3 baños', 'results': 16066}, {'id': '[4-4]', 'name': '4 baños', 'results': 3944}, {'id': '[5-*)', 'name': '5 baños o más', 'results': 1160}]
# --------------------------------------------------
# 12 -> id = HAS_AIR_CONDITIONING:
# Otras características[boolean]: [{'id': '242085', 'name': 'Con aire acondicionado', 'results': 62002}]
# --------------------------------------------------
# 13 -> id = HAS_GARDEN:
# Otras características[boolean]: [{'id': '242085', 'name': 'Con jardín', 'results': 14558}]
# --------------------------------------------------
# 14 -> id = HAS_GRILL:
# Otras características[boolean]: [{'id': '242085', 'name': 'Con parrilla', 'results': 44544}]
# --------------------------------------------------
# 15 -> id = HAS_GYM:
# Otras características[boolean]: [{'id': '242085', 'name': 'Con gimnasio', 'results': 36366}]
# --------------------------------------------------
# 16 -> id = HAS_HALF_BATH:
# Otras características[boolean]: [{'id': '242085', 'name': 'Con toilette', 'results': 49474}]
# --------------------------------------------------
# 17 -> id = HAS_MULTIPURPOSE_ROOM:
# Otras características[boolean]: [{'id': '242085', 'name': 'Con salón de usos múltiples', 'results': 47850}]
# --------------------------------------------------
# 18 -> id = HAS_SWIMMING_POOL:
# Otras características[boolean]: [{'id': '242085', 'name': 'Con pileta', 'results': 60436}]
# --------------------------------------------------
# 19 -> id = IS_FINANCEABLE:
# Financiable[boolean]: [{'id': '242085', 'name': 'Es financiable', 'results': 10730}]
# --------------------------------------------------
# 20 -> id = ITEM_CONDITION:
# Condición[STRING]: [{'id': '2230581', 'name': 'Usado', 'results': 160892}, {'id': '2230284', 'name': 'Nuevo', 'results': 112810}]
# --------------------------------------------------
# 21 -> id = MAINTENANCE_FEE:
# Expensas[range]: [{'id': '(*-3000ARS)', 'name': '3.000 ARS o menos', 'results': 122786}, {'id': '[3000ARS-5500ARS]', 'name': '3.000 a 5.500 ARS', 'results': 22330}, {'id': '[5500ARS-10000ARS]', 'name': '5.500 a 10.000 ARS', 'results': 23200}, {'id': '[10000ARS-*)', 'name': '10.000 ARS o más', 'results': 41702}]
# --------------------------------------------------
# 22 -> id = OPERATION:
# Operación[STRING]: [{'id': '242075', 'name': 'Venta', 'results': 265814}, {'id': '242074', 'name': 'Alquiler temporal', 'results': 18328}, {'id': '242073', 'name': 'Alquiler', 'results': 10672}]
# --------------------------------------------------
# 23 -> id = OPERATION_SUBTYPE:
# Modalidad[STRING]: [{'id': '244562', 'name': 'Propiedades individuales', 'results': 265060}, {'id': '245034', 'name': 'Emprendimientos', 'results': 1508}]
# --------------------------------------------------
# 24 -> id = PARKING_LOTS:
# Cocheras[range]: [{'id': '[0-0]', 'name': 'No tiene cocheras', 'results': 195170}, {'id': '[1-1]', 'name': '1 cochera', 'results': 89958}, {'id': '[2-2]', 'name': '2 cocheras', 'results': 9106}, {'id': '[3-3]', 'name': '3 cocheras', 'results': 290}, {'id': '[4-*)', 'name': '4 cocheras o más', 'results': 928}]
# --------------------------------------------------
# 25 -> id = PROFESSIONAL_USE_ALLOWED:
# Otras características[boolean]: [{'id': '242085', 'name': 'Apto profesional', 'results': 30914}]
# --------------------------------------------------
# 26 -> id = PROPERTY_AGE:
# Antigüedad[range]: [{'id': '[0años-0años]', 'name': 'A estrenar', 'results': 98890}, {'id': '[1años-9años]', 'name': '1 a 9 años', 'results': 41064}, {'id': '[9años-30años]', 'name': '9 a 30 años', 'results': 35032}, {'id': '[30años-50años]', 'name': '30 a 50 años', 'results': 31784}, {'id': '[50años-*)', 'name': '50 años o más', 'results': 9338}]
# --------------------------------------------------
# 27 -> id = PROPERTY_TYPE:
# Inmueble[STRING]: [{'id': '242062', 'name': 'Departamentos', 'results': 294814}]
# --------------------------------------------------
# 28 -> id = ROOMS:
# Ambientes[range]: [{'id': '[1-1]', 'name': '1 ambiente', 'results': 48778}, {'id': '[2-2]', 'name': '2 ambientes', 'results': 106604}, {'id': '[3-3]', 'name': '3 ambientes', 'results': 82360}, {'id': '[4-*)', 'name': '4 ambientes o más', 'results': 50634}]
# --------------------------------------------------
# 29 -> id = SUITABLE_FOR_MORTGAGE_LOAN:
# Apto crédito[boolean]: [{'id': '242085', 'name': 'Es apto crédito', 'results': 33814}]
# --------------------------------------------------
# 30 -> id = TOTAL_AREA:
# Superficie total[range]: [{'id': '(*-45m²]', 'name': '45 m² totales o menos', 'results': 87406}, {'id': '²-60m²]', 'name': '45 a 60 m² totales', 'results': 74182}, {'id': '²-85m²]', 'name': '60 a 85 m² totales', 'results': 68904}, {'id': '²-*)', 'name': '85 m² totales o más', 'results': 78300}]
# --------------------------------------------------
# 31 -> id = WITH_VIRTUAL_TOUR:
# Multimedia[boolean]: [{'id': '242085', 'name': 'Tour virtual', 'results': 696}]
# --------------------------------------------------

# %% [markdown]
# #### Resumen _'_available_filter_'_
#
# Para atomizar el pedido a la API de ML se puede aplicar diferentes filtros concatenados utlizando
# * Grupo de la búsqueda:
#     /search?q=id o /search?category=id
# * Filtros concatendados:
#     &FilterID=FilterValue&FilterID=FilterValue
#
# ejemplo:
# URI:
# 'https://api.mercadolibre.com/sites/MLA/'
#
# | Búsqueda |  q_id_filter| category_id_filter|
# | --- | --- | --- |
# | propiedades = Departamento | /search?q=Departamentos | /search?category=MLA1472|
#
# URI:
# 'https://api.mercadolibre.com/sites/MLA/search?category=MLA1472'
#
# | Filtro | filter_key | value | syntax |
# | --- | --- | --- | --- |
# | Antigüedad = 6 a 25 años | PROPERTY_AGE | [6años-25años] | &PROPERTY_AGE=[6años-25años] |
# | Ambientes = 3 y 4 | ROOMS | [3-4] | &ROOMS=[3-4] |
# | Ubicación = Capital Federal | state | TUxBUENBUGw3M2E1 | &state=TUxBUENBUGw3M2E1 |
#
#
# URI:
# 'https://api.mercadolibre.com/sites/MLA/search?category=MLA1472&PROPERTY_AGE=[6años-25años]&ROOMS=[3-4]&state=TUxBUENBUGw3M2E1'

# %% [markdown]
# ## Inspección de 'results'

# %%
# # results
len(data['results']), type(data['results'])
# Out:
# (3, list)

# %% [markdown]
# Es una lista con un solo contenido.
# Veamos que tiene un dict con 41 varialbes.

# %%
# results, largo, tipo y contenidos.
len(data['results'][0]), type(data['results'][0]), data['results'][0].keys()
# Out:
# (41,
#  dict,
#  dict_keys(['id', 'site_id', 'title', 'seller', 'price', 'prices', 'sale_price', 'currency_id', 'available_quantity', 'sold_quantity', 'buying_mode', 'listing_type_id', 'stop_time', 'condition', 'permalink', 'thumbnail', 'thumbnail_id', 'accepts_mercadopago', 'installments', 'address', 'promotions', 'shipping', 'seller_address', 'seller_contact', 'location', 'attributes', 'original_price', 'category_id', 'official_store_id', 'domain_id', 'catalog_product_id', 'tags', 'order_backend', 'use_thumbnail_id', 'offer_score', 'offer_share', 'match_score', 'winner_item_id', 'melicoin', 'discounts', 'inventory_id']))

# %% [markdown]
# Conte nidos de results[0].

# %%
# results
for i, k in enumerate (data['results'][0]):
    if k != 'attributes':
        print(f'{i} -> id = {k}:\nValue = {data["results"][0][k]}')#: {ty["title"]}', end="\n")
        print(50*'-')
# Out:
# 0 -> id = id:
# Value = MLA1218638438
# --------------------------------------------------
# 1 -> id = site_id:
# Value = MLA
# --------------------------------------------------
# 2 -> id = title:
# Value = Departamento. Semipiso. 4 Ambientes. Balcon Corrido
# --------------------------------------------------
# 3 -> id = seller:
# Value = {'id': 169745983, 'permalink': 'http://perfil.mercadolibre.com.ar/DIMITRI+PROPIEDADES', 'registration_date': '2014-10-28T11:40:40.000-04:00', 'car_dealer': False, 'real_estate_agency': True, 'tags': ['real_estate_agency', 'nsm_low', 'messages_as_seller'], 'home_image_url': 'https://resources.mlstatic.com/classifieds_accounts/MLA_real_estate_agency/169745983_home.png', 'seller_reputation': {'power_seller_status': None, 'level_id': None, 'metrics': {'cancellations': {'period': '365 days', 'rate': 0, 'value': 0}, 'claims': {'period': '365 days', 'rate': 0, 'value': 0}, 'delayed_handling_time': {'period': '365 days', 'rate': 0, 'value': 0}, 'sales': {'period': '365 days', 'completed': 0}}, 'transactions': {'canceled': 0, 'period': 'historic', 'total': 0, 'ratings': {'negative': 0, 'neutral': 0, 'positive': 0}, 'completed': 0}}}
# --------------------------------------------------
# 4 -> id = price:
# Value = 118000
# --------------------------------------------------
# 5 -> id = prices:
# Value = {'id': 'MLA1218638438', 'prices': [{'id': '1', 'type': 'standard', 'amount': 118000, 'regular_amount': None, 'currency_id': 'USD', 'last_updated': '2022-10-31T01:52:20Z', 'conditions': {'context_restrictions': [], 'start_time': None, 'end_time': None, 'eligible': True}, 'exchange_rate_context': 'DEFAULT', 'metadata': {}}], 'presentation': {'display_currency': 'USD'}, 'payment_method_prices': [], 'reference_prices': [], 'purchase_discounts': []}
# --------------------------------------------------
# 6 -> id = sale_price:
# Value = None
# --------------------------------------------------
# 7 -> id = currency_id:
# Value = USD
# --------------------------------------------------
# 8 -> id = available_quantity:
# Value = 1
# --------------------------------------------------
# 9 -> id = sold_quantity:
# Value = 0
# --------------------------------------------------
# 10 -> id = buying_mode:
# Value = classified
# --------------------------------------------------
# 11 -> id = listing_type_id:
# Value = gold_premium
# --------------------------------------------------
# 12 -> id = stop_time:
# Value = 2023-10-30T04:00:00.000Z
# --------------------------------------------------
# 13 -> id = condition:
# Value = used
# --------------------------------------------------
# 14 -> id = permalink:
# Value = https://departamento.mercadolibre.com.ar/MLA-1218638438-departamento-semipiso-4-ambientes-balcon-corrido-_JM
# --------------------------------------------------
# 15 -> id = thumbnail:
# Value = http://http2.mlstatic.com/D_988677-MLA52207303729_102022-I.jpg
# --------------------------------------------------
# 16 -> id = thumbnail_id:
# Value = 988677-MLA52207303729_102022
# --------------------------------------------------
# 17 -> id = accepts_mercadopago:
# Value = False
# --------------------------------------------------
# 18 -> id = installments:
# Value = None
# --------------------------------------------------
# 19 -> id = address:
# Value = {'state_id': 'TUxBUENBUGw3M2E1', 'state_name': 'Capital Federal', 'city_id': 'TUxBQ0NBUGZlZG1sYQ', 'city_name': 'Capital Federal', 'area_code': '', 'phone1': ''}
# --------------------------------------------------
# 20 -> id = promotions:
# Value = None
# --------------------------------------------------
# 21 -> id = shipping:
# Value = {'free_shipping': False, 'mode': 'not_specified', 'tags': [], 'logistic_type': 'not_specified', 'store_pick_up': False}
# --------------------------------------------------
# 22 -> id = seller_address:
# Value = {'id': '', 'comment': '', 'address_line': '', 'zip_code': '', 'country': {'id': 'AR', 'name': 'Argentina'}, 'state': {'id': 'AR-C', 'name': 'Capital Federal'}, 'city': {'id': None, 'name': 'Capital Federal'}, 'latitude': '', 'longitude': ''}
# --------------------------------------------------
# 23 -> id = seller_contact:
# Value = {'contact': 'Dimitri Propiedades • CUCICBA 6110', 'other_info': '', 'area_code': '', 'phone': '', 'area_code2': '', 'phone2': '', 'email': '', 'webpage': ''}
# --------------------------------------------------
# 24 -> id = location:
# Value = {'address_line': 'RIO DE Janeiro 40', 'zip_code': '', 'subneighborhood': None, 'neighborhood': {'id': 'TUxBQkNBQjM4MDda', 'name': 'Caballito'}, 'city': {'id': 'TUxBQ0NBUGZlZG1sYQ', 'name': 'Capital Federal'}, 'state': {'id': 'TUxBUENBUGw3M2E1', 'name': 'Capital Federal'}, 'country': {'id': 'AR', 'name': 'Argentina'}, 'latitude': -34.61502, 'longitude': -58.430195}
# --------------------------------------------------
# 26 -> id = original_price:
# Value = None
# --------------------------------------------------
# 27 -> id = category_id:
# Value = MLA401686
# --------------------------------------------------
# 28 -> id = official_store_id:
# Value = None
# --------------------------------------------------
# 29 -> id = domain_id:
# Value = MLA-INDIVIDUAL_APARTMENTS_FOR_SALE
# --------------------------------------------------
# 30 -> id = catalog_product_id:
# Value = None
# --------------------------------------------------
# 31 -> id = tags:
# Value = ['good_quality_picture', 'good_quality_thumbnail']
# --------------------------------------------------
# 32 -> id = order_backend:
# Value = 1
# --------------------------------------------------
# 33 -> id = use_thumbnail_id:
# Value = True
# --------------------------------------------------
# 34 -> id = offer_score:
# Value = None
# --------------------------------------------------
# 35 -> id = offer_share:
# Value = None
# --------------------------------------------------
# 36 -> id = match_score:
# Value = None
# --------------------------------------------------
# 37 -> id = winner_item_id:
# Value = None
# --------------------------------------------------
# 38 -> id = melicoin:
# Value = None
# --------------------------------------------------
# 39 -> id = discounts:
# Value = None
# --------------------------------------------------
# 40 -> id = inventory_id:
# Value = None
# --------------------------------------------------

# %% [markdown]
# ### Vemos que hay dentro de '_results_' '_attributes_'

# %%
# keys.
list(data['results'][0]['attributes'][0].keys())
# Out:
# ['name',
#  'value_struct',
#  'values',
#  'source',
#  'value_type',
#  'id',
#  'value_id',
#  'value_name',
#  'attribute_group_id',
#  'attribute_group_name']

# %%
for i, attr in enumerate(data['results'][0]['attributes']):
    print(f'{i} -> id = {attr["id"]}:\n')
    pprint(attr)
    print(50*'-')
# Out:
# 0 -> id = HAS_AIR_CONDITIONING:
#
# {'attribute_group_id': 'COMOYAMEN',
#  'attribute_group_name': 'Comodidades y amenities',
#  'id': 'HAS_AIR_CONDITIONING',
#  'name': 'Aire acondicionado',
#  'source': 4709975701260268,
#  'value_id': '242085',
#  'value_name': 'Sí',
#  'value_struct': None,
#  'value_type': 'boolean',
#  'values': [{'id': '242085',
#              'name': 'Sí',
#              'source': 4709975701260268,
#              'struct': None}]}
# --------------------------------------------------
# 1 -> id = HAS_TELEPHONE_LINE:
#
# {'attribute_group_id': 'COMOYAMEN',
#  'attribute_group_name': 'Comodidades y amenities',
#  'id': 'HAS_TELEPHONE_LINE',
#  'name': 'Línea telefónica',
#  'source': 4709975701260268,
#  'value_id': '242084',
#  'value_name': 'No',
#  'value_struct': None,
#  'value_type': 'boolean',
#  'values': [{'id': '242084',
#              'name': 'No',
#              'source': 4709975701260268,
#              'struct': None}]}
# --------------------------------------------------
# 2 -> id = BEDROOMS:
#
# {'attribute_group_id': 'FIND',
#  'attribute_group_name': 'Ficha técnica',
#  'id': 'BEDROOMS',
#  'name': 'Dormitorios',
#  'source': 4709975701260268,
#  'value_id': None,
#  'value_name': '3',
#  'value_struct': None,
#  'value_type': 'number',
#  'values': [{'id': None,
#              'name': '3',
#              'source': 4709975701260268,
#              'struct': None}]}
# --------------------------------------------------
# 3 -> id = COVERED_AREA:
#
# {'attribute_group_id': 'FIND',
#  'attribute_group_name': 'Ficha técnica',
#  'id': 'COVERED_AREA',
#  'name': 'Superficie cubierta',
#  'source': 4709975701260268,
#  'value_id': None,
#  'value_name': '80 m²',
#  'value_struct': {'number': 80, 'unit': 'm²'},
#  'value_type': 'number_unit',
#  'values': [{'id': None,
#              'name': '80 m²',
#              'source': 4709975701260268,
#              'struct': {'number': 80, 'unit': 'm²'}}]}
# --------------------------------------------------
# 4 -> id = FULL_BATHROOMS:
#
# {'attribute_group_id': 'FIND',
#  'attribute_group_name': 'Ficha técnica',
#  'id': 'FULL_BATHROOMS',
#  'name': 'Baños',
#  'source': 4709975701260268,
#  'value_id': None,
#  'value_name': '1',
#  'value_struct': None,
#  'value_type': 'number',
#  'values': [{'id': None,
#              'name': '1',
#              'source': 4709975701260268,
#              'struct': None}]}
# --------------------------------------------------
# 5 -> id = ROOMS:
#
# {'attribute_group_id': 'FIND',
#  'attribute_group_name': 'Ficha técnica',
#  'id': 'ROOMS',
#  'name': 'Ambientes',
#  'source': 4709975701260268,
#  'value_id': None,
#  'value_name': '4',
#  'value_struct': None,
#  'value_type': 'number',
#  'values': [{'id': None,
#              'name': '4',
#              'source': 4709975701260268,
#              'struct': None}]}
# --------------------------------------------------
# 6 -> id = TOTAL_AREA:
#
# {'attribute_group_id': 'FIND',
#  'attribute_group_name': 'Ficha técnica',
#  'id': 'TOTAL_AREA',
#  'name': 'Superficie total',
#  'source': 4709975701260268,
#  'value_id': None,
#  'value_name': '0 m²',
#  'value_struct': {'number': 0, 'unit': 'm²'},
#  'value_type': 'number_unit',
#  'values': [{'id': None,
#              'name': '0 m²',
#              'source': 4709975701260268,
#              'struct': {'number': 0, 'unit': 'm²'}}]}
# --------------------------------------------------
# 7 -> id = OPERATION:
#
# {'attribute_group_id': 'MAIN',
#  'attribute_group_name': 'Principales',
#  'id': 'OPERATION',
#  'name': 'Operación',
#  'source': 1,
#  'value_id': '242075',
#  'value_name': 'Venta',
#  'value_struct': None,
#  'value_type': 'list',
#  'values': [{'id': '242075', 'name': 'Venta', 'source': 1, 'struct': None}]}
# --------------------------------------------------
# 8 -> id = PROPERTY_TYPE:
#
# {'attribute_group_id': 'MAIN',
#  'attribute_group_name': 'Principales',
#  'id': 'PROPERTY_TYPE',
#  'name': 'Inmueble',
#  'source': 1,
#  'value_id': '242062',
#  'value_name': 'Departamento',
#  'value_struct': None,
#  'value_type': 'list',
#  'values': [{'id': '242062',
#              'name': 'Departamento',
#              'source': 1,
#              'struct': None}]}
# --------------------------------------------------
# 9 -> id = ITEM_CONDITION:
#
# {'attribute_group_id': 'OTHERS',
#  'attribute_group_name': 'Otros',
#  'id': 'ITEM_CONDITION',
#  'name': 'Condición del ítem',
#  'source': 1,
#  'value_id': '2230581',
#  'value_name': 'Usado',
#  'value_struct': None,
#  'value_type': 'list',
#  'values': [{'id': '2230581', 'name': 'Usado', 'source': 1, 'struct': None}]}
# --------------------------------------------------
# 10 -> id = WITH_VIRTUAL_TOUR:
#
# {'attribute_group_id': 'OTHERS',
#  'attribute_group_name': 'Otros',
#  'id': 'WITH_VIRTUAL_TOUR',
#  'name': 'Tour virtual',
#  'source': 942334329061206,
#  'value_id': '242084',
#  'value_name': 'No',
#  'value_struct': None,
#  'value_type': 'boolean',
#  'values': [{'id': '242084',
#              'name': 'No',
#              'source': 942334329061206,
#              'struct': None}]}
# --------------------------------------------------

# %%
data['results'][0]['seller']['real_estate_agency']
# Out:
# True

# %% [markdown]
# # Buscando los datos de interes
#
#  id     | header | type | description | location|
#  :----: | :----: | :----: | :---- | :----
#  0  | id           | [str] | Identificador de la publicación, permite .../items/id_items| data['results'][0]['id']
#  1  | star_date    | [dtime] | Inicio de la publicación, solo puedo acceder si ingreso a cada publicación| .../items/id_items
#  2  | end_date     | [dtime] | Fecha en la que se programa el fin de la publicación| data['results'][0]['stop_time']
#  3  | last_update  | [dtime]| Última actualización del precio publicado           | data['results'][0]['prices']['prices']['last_updated']
#  4  | seller_type  | [bool] | Publicado por agente imobiliario o tiendas oficiales| data['results'][0]['seller']['real_estate_agency']
#  5  | title        | [str] | Título de la publicación                             | data['results'][0]['title']
#  6  | condition    | [str] | Describe si el inmueble es nuevo o usado             | data['results'][0]['condition']
#  7  | property_type| [str] | Departamento, casa, PH, casa quinta                  | data['results'][0]['attributes'][{'id':'PROPERTY_TYPE', 'value_name': "n"}]
#  8  | rooms        | [int] | Cantidad de ambientes                                | data['results'][0]['attributes'][{'id':'ROOMS', 'value_name': 'n'}]
#  9  | bathrooms    | [int] | Cantidad de baños                                    | data['results'][0]['attributes'][{'id':'FULL_BATHROOMS', 'value_name': 'n'}]
#  10 | bedrooms     | [int] | Cantidad de dormitorios                              | data['results'][0]['attributes'][{'id':'BEDROOMS', 'value_name': "n"}]
#  11 | operation_type | [str] | Alquiler, alquiler temporal, venta                 | data['results'][0]['attributes'][{'id':'OPERATION', 'value_name': "n"}]
#  12 | currency     | [str] | Típo de moneda                                       | data['results'][0]['currency_id']
#  13 | price        | [float] | Importe publicado del tipo de operación            | data['results'][0]['price']
#  14 | surface_covered | [float] | Supeficie cubierta en m²                        | data['results'][0]['attributes'][{'id':'COVERED_AREA', 'value_name': "n"}]
#  15 | surface_tota | [float] | Supeficie total en m²                              | data['results'][0]['attributes'][{'id':'TOTAL_AREA', 'value_name': "n"}]
#  16 | real_estate_agency | [bool] | Publicado por inmobiliaria                    | data['results'][0]['seller']['real_estate_agency']
#  17 | country      | [float] | Identificador del pasí ej. "AR" Argentina          | data['results'][0]['location']['country][name']
#  18 | state        | [str] | Región, zona, localidades ej. Bs.As. G.B.A. Oeste    | data['results'][0]['location']['state']['name']
#  19 | city         | [str] | Ciudad, Partido ej. La Matanza, Capital Federal      | data['results'][0]['location']['city']['name']
#  20 | neighborhood | [str] | Localidad, Barrio, vecindario ej. Ramos Mejía, Belgrano| data['results'][0]['location']['neighborhood']['name']
#  21 | lat          | [float] | Latitud                                            | data['results'][0]['location']['latitude']
#  22 | lon          | [float] | Longitud                                           | data['results'][0]['location']['longitude']

# %%
# requests.get("https://api.mercadolibre.com/items/MLA1214335876")
# df = pd.json_normalize()

# %%
df = pd.json_normalize(data, "results")

# %%
pd.json_normalize(df['attributes'])
# Out:
#                                                   0   \
# 0  {'id': 'HAS_TELEPHONE_LINE', 'value_name': 'Sí...
# 1  {'attribute_group_name': 'Características adic...
# 2  {'value_id': None, 'value_struct': None, 'valu...
#
#                                                   1   \
# 0  {'value_name': 'Sí', 'attribute_group_id': 'CO...
# 1  {'id': 'HAS_AIR_CONDITIONING', 'values': [{'id...
# 2  {'attribute_group_id': 'FIND', 'attribute_grou...
#
#                                                   2   \
# 0  {'source': 6316276763983939, 'id': 'BEDROOMS',...
# 1  {'attribute_group_name': 'Ficha técnica', 'sou...
# 2  {'name': 'Baños', 'value_id': None, 'values': ...
#
#                                                   3   \
# 0  {'source': 6316276763983939, 'value_type': 'nu...
# 1  {'value_id': None, 'attribute_group_id': 'FIND...
# 2  {'attribute_group_name': 'Ficha técnica', 'sou...
#
#                                                   4   \
# 0  {'value_name': '1', 'attribute_group_id': 'FIN...
# 1  {'value_id': None, 'value_name': '1', 'value_s...
# 2  {'id': 'TOTAL_AREA', 'name': 'Superficie total...
#
#                                                   5   \
# 0  {'attribute_group_name': 'Ficha técnica', 'sou...
# 1  {'source': 7092, 'value_id': None, 'value_stru...
# 2  {'attribute_group_id': 'MAIN', 'attribute_grou...
#
#                                                   6   \
# 0  {'value_type': 'number_unit', 'values': [{'id'...
# 1  {'source': 7092, 'value_type': 'number_unit', ...
# 2  {'name': 'Inmueble', 'value_struct': None, 'va...
#
#                                                   7   \
# 0  {'id': 'OPERATION', 'name': 'Operación', 'valu...
# 1  {'value_name': 'Alquiler temporal', 'attribute...
# 2  {'attribute_group_id': 'OTHERS', 'attribute_gr...
#
#                                                   8   \
# 0  {'id': 'PROPERTY_TYPE', 'value_id': '242062', ...
# 1  {'name': 'Inmueble', 'value_id': '242062', 'va...
# 2  {'attribute_group_id': 'OTHERS', 'source': 942...
#
#                                                   9   \
# 0  {'id': 'ITEM_CONDITION', 'name': 'Condición de...
# 1  {'id': 'WITH_VIRTUAL_TOUR', 'value_name': 'No'...
# 2                                               None
#
#                                                   10
# 0  {'values': [{'struct': None, 'source': 9423343...
# 1                                               None
# 2                                               None

# %%
df.columns.to_list()
# Out:
# ['id',
#  'site_id',
#  'title',
#  'price',
#  'sale_price',
#  'currency_id',
#  'available_quantity',
#  'sold_quantity',
#  'buying_mode',
#  'listing_type_id',
#  'stop_time',
#  'condition',
#  'permalink',
#  'thumbnail',
#  'thumbnail_id',
#  'accepts_mercadopago',
#  'installments',
#  'promotions',
#  'attributes',
#  'original_price',
#  'category_id',
#  'official_store_id',
#  'domain_id',
#  'catalog_product_id',
#  'tags',
#  'order_backend',
#  'use_thumbnail_id',
#  'offer_score',
#  'offer_share',
#  'match_score',
#  'winner_item_id',
#  'melicoin',
#  'discounts',
#  'inventory_id',
#  'seller.id',
#  'seller.permalink',
#  'seller.registration_date',
#  'seller.car_dealer',
#  'seller.real_estate_agency',
#  'seller.tags',
#  'seller.seller_reputation.power_seller_status',
#  'seller.seller_reputation.level_id',
#  'seller.seller_reputation.metrics.cancellations.period',
#  'seller.seller_reputation.metrics.cancellations.rate',
#  'seller.seller_reputation.metrics.cancellations.value',
#  'seller.seller_reputation.metrics.claims.period',
#  'seller.seller_reputation.metrics.claims.rate',
#  'seller.seller_reputation.metrics.claims.value',
#  'seller.seller_reputation.metrics.delayed_handling_time.period',
#  'seller.seller_reputation.metrics.delayed_handling_time.rate',
#  'seller.seller_reputation.metrics.delayed_handling_time.value',
#  'seller.seller_reputation.metrics.sales.period',
#  'seller.seller_reputation.metrics.sales.completed',
#  'seller.seller_reputation.transactions.canceled',
#  'seller.seller_reputation.transactions.period',
#  'seller.seller_reputation.transactions.total',
#  'seller.seller_reputation.transactions.ratings.negative',
#  'seller.seller_reputation.transactions.ratings.neutral',
#  'seller.seller_reputation.transactions.ratings.positive',
#  'seller.seller_reputation.transactions.completed',
#  'prices.id',
#  'prices.prices',
#  'prices.presentation.display_currency',
#  'prices.payment_method_prices',
#  'prices.reference_prices',
#  'prices.purchase_discounts',
#  'address.state_id',
#  'address.state_name',
#  'address.city_id',
#  'address.city_name',
#  'address.area_code',
#  'address.phone1',
#  'shipping.free_shipping',
#  'shipping.mode',
#  'shipping.tags',
#  'shipping.logistic_type',
#  'shipping.store_pick_up',
#  'seller_address.id',
#  'seller_address.comment',
#  'seller_address.address_line',
#  'seller_address.zip_code',
#  'seller_address.country.id',
#  'seller_address.country.name',
#  'seller_address.state.id',
#  'seller_address.state.name',
#  'seller_address.city.id',
#  'seller_address.city.name',
#  'seller_address.latitude',
#  'seller_address.longitude',
#  'seller_contact.contact',
#  'seller_contact.other_info',
#  'seller_contact.area_code',
#  'seller_contact.phone',
#  'seller_contact.area_code2',
#  'seller_contact.phone2',
#  'seller_contact.email',
#  'seller_contact.webpage',
#  'location.address_line',
#  'location.zip_code',
#  'location.subneighborhood',
#  'location.neighborhood.id',
#  'location.neighborhood.name',
#  'location.city.id',
#  'location.city.name',
#  'location.state.id',
#  'location.state.name',
#  'location.country.id',
#  'location.country.name',
#  'location.latitude',
#  'location.longitude']

# %%
# data = json.loads(r.content)
#import flatdict

# %%
pd.json_normalize(data, record_path = 'results', sep='-').columns.to_list()
# Out:
# ['id',
#  'site_id',
#  'title',
#  'price',
#  'sale_price',
#  'currency_id',
#  'available_quantity',
#  'sold_quantity',
#  'buying_mode',
#  'listing_type_id',
#  'stop_time',
#  'condition',
#  'permalink',
#  'thumbnail',
#  'thumbnail_id',
#  'accepts_mercadopago',
#  'installments',
#  'promotions',
#  'attributes',
#  'original_price',
#  'category_id',
#  'official_store_id',
#  'domain_id',
#  'catalog_product_id',
#  'tags',
#  'order_backend',
#  'use_thumbnail_id',
#  'offer_score',
#  'offer_share',
#  'match_score',
#  'winner_item_id',
#  'melicoin',
#  'discounts',
#  'inventory_id',
#  'seller-id',
#  'seller-permalink',
#  'seller-registration_date',
#  'seller-car_dealer',
#  'seller-real_estate_agency',
#  'seller-tags',
#  'seller-seller_reputation-power_seller_status',
#  'seller-seller_reputation-level_id',
#  'seller-seller_reputation-metrics-cancellations-period',
#  'seller-seller_reputation-metrics-cancellations-rate',
#  'seller-seller_reputation-metrics-cancellations-value',
#  'seller-seller_reputation-metrics-claims-period',
#  'seller-seller_reputation-metrics-claims-rate',
#  'seller-seller_reputation-metrics-claims-value',
#  'seller-seller_reputation-metrics-delayed_handling_time-period',
#  'seller-seller_reputation-metrics-delayed_handling_time-rate',
#  'seller-seller_reputation-metrics-delayed_handling_time-value',
#  'seller-seller_reputation-metrics-sales-period',
#  'seller-seller_reputation-metrics-sales-completed',
#  'seller-seller_reputation-transactions-canceled',
#  'seller-seller_reputation-transactions-period',
#  'seller-seller_reputation-transactions-total',
#  'seller-seller_reputation-transactions-ratings-negative',
#  'seller-seller_reputation-transactions-ratings-neutral',
#  'seller-seller_reputation-transactions-ratings-positive',
#  'seller-seller_reputation-transactions-completed',
#  'prices-id',
#  'prices-prices',
#  'prices-presentation-display_currency',
#  'prices-payment_method_prices',
#  'prices-reference_prices',
#  'prices-purchase_discounts',
#  'address-state_id',
#  'address-state_name',
#  'address-city_id',
#  'address-city_name',
#  'address-area_code',
#  'address-phone1',
#  'shipping-free_shipping',
#  'shipping-mode',
#  'shipping-tags',
#  'shipping-logistic_type',
#  'shipping-store_pick_up',
#  'seller_address-id',
#  'seller_address-comment',
#  'seller_address-address_line',
#  'seller_address-zip_code',
#  'seller_address-country-id',
#  'seller_address-country-name',
#  'seller_address-state-id',
#  'seller_address-state-name',
#  'seller_address-city-id',
#  'seller_address-city-name',
#  'seller_address-latitude',
#  'seller_address-longitude',
#  'seller_contact-contact',
#  'seller_contact-other_info',
#  'seller_contact-area_code',
#  'seller_contact-phone',
#  'seller_contact-area_code2',
#  'seller_contact-phone2',
#  'seller_contact-email',
#  'seller_contact-webpage',
#  'location-address_line',
#  'location-zip_code',
#  'location-subneighborhood',
#  'location-neighborhood-id',
#  'location-neighborhood-name',
#  'location-city-id',
#  'location-city-name',
#  'location-state-id',
#  'location-state-name',
#  'location-country-id',
#  'location-country-name',
#  'location-latitude',
#  'location-longitude']

# %%
df = pd.json_normalize(data, "results")

# %%
#requests.get(api).json()
#pd.DataFrame.from_dict(df.attributes)['attributes'].to_dict()

# %%
df.filter(regex=("prices-*"))
# Out:
#        prices.id                                      prices.prices  \
# 0  MLA1214575464  [{'id': '1', 'type': 'standard', 'amount': 350...
# 1  MLA1214335876  [{'id': '4', 'type': 'standard', 'amount': 110...
# 2  MLA1214352880  [{'id': '1', 'type': 'standard', 'amount': 120...
#
#   prices.presentation.display_currency prices.payment_method_prices  \
# 0                                  ARS                           []
# 1                                  ARS                           []
# 2                                  ARS                           []
#
#                              prices.reference_prices prices.purchase_discounts
# 0                                                 []                        []
# 1  [{'id': '5', 'type': 'min_standard', 'conditio...                        []
# 2                                                 []                        []

# %%
data[]
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'paging': {'total': 300926, 'primary_results': 1000, 'offset': 0, 'limit': 3},
#  'results': [{'id': 'MLA1214140056',
#    'site_id': 'MLA',
#    'title': 'Triplex 3 Amb . 94 M² . Frente . Balcón . Terraza C/parrilla . 2 Cocheras . Muy Luminoso',
#    'seller': {'id': 1120816653,
#     'permalink': 'http://perfil.mercadolibre.com.ar/REALPROPSREALPROPS',
#     'registration_date': '2022-08-09T14:01:54.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': True,
#     'tags': ['real_estate_agency', 'messages_as_seller'],
#     'seller_reputation': {'level_id': None,
#      'power_seller_status': None,
#      'transactions': {'canceled': 0,
#       'completed': 0,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'neutral': 0, 'positive': 0},
#       'total': 0},
#      'metrics': {'sales': {'period': '365 days', 'completed': 0},
#       'claims': {'period': '365 days', 'rate': 0, 'value': 0},
#       'delayed_handling_time': {'period': '365 days', 'rate': 0, 'value': 0},
#       'cancellations': {'period': '365 days', 'rate': 0, 'value': 0}}}},
#    'price': 185000,
#    'prices': {'id': 'MLA1214140056',
#     'prices': [{'id': '1',
#       'type': 'standard',
#       'amount': 185000,
#       'regular_amount': None,
#       'currency_id': 'USD',
#       'last_updated': '2022-10-26T14:11:03Z',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {}}],
#     'presentation': {'display_currency': 'USD'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'USD',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'classified',
#    'listing_type_id': 'gold_premium',
#    'stop_time': '2023-10-26T04:00:00.000Z',
#    'condition': 'used',
#    'permalink': 'https://departamento.mercadolibre.com.ar/MLA-1214140056-triplex-3-amb-94-m-frente-balcon-terraza-cparrilla-2-cocheras-muy-luminoso-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_951273-MLA52142270215_102022-I.jpg',
#    'thumbnail_id': '951273-MLA52142270215_102022',
#    'accepts_mercadopago': False,
#    'installments': None,
#    'address': {'state_id': 'TUxBUENBUGw3M2E1',
#     'state_name': 'Capital Federal',
#     'city_id': 'TUxBQ0NBUGZlZG1sYQ',
#     'city_name': 'Capital Federal',
#     'area_code': '',
#     'phone1': ''},
#    'promotions': None,
#    'shipping': {'free_shipping': False,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': 'not_specified',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#     'city': {'id': 'TUxBQlBBTDI1MTVa', 'name': 'Palermo'},
#     'latitude': '',
#     'longitude': ''},
#    'seller_contact': {'contact': 'Miguel Pollola',
#     'other_info': '',
#     'area_code': '',
#     'phone': '',
#     'area_code2': '',
#     'phone2': '',
#     'email': '',
#     'webpage': ''},
#    'location': {'address_line': 'Rómulo Naón al 3500',
#     'zip_code': '',
#     'subneighborhood': None,
#     'neighborhood': {'id': 'TUxBQkJFTDcyNTJa', 'name': 'Belgrano'},
#     'city': {'id': 'TUxBQ0NBUGZlZG1sYQ', 'name': 'Capital Federal'},
#     'state': {'id': 'TUxBUENBUGw3M2E1', 'name': 'Capital Federal'},
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'latitude': -34.556736,
#     'longitude': -58.481},
#    'attributes': [{'value_name': 'Sí',
#      'value_struct': None,
#      'source': 4709975701260268,
#      'value_type': 'boolean',
#      'id': 'HAS_AIR_CONDITIONING',
#      'name': 'Aire acondicionado',
#      'value_id': '242085',
#      'values': [{'id': '242085',
#        'name': 'Sí',
#        'struct': None,
#        'source': 4709975701260268}],
#      'attribute_group_id': 'COMOYAMEN',
#      'attribute_group_name': 'Comodidades y amenities'},
#     {'value_struct': None,
#      'attribute_group_id': 'COMOYAMEN',
#      'id': 'HAS_TELEPHONE_LINE',
#      'name': 'Línea telefónica',
#      'value_id': '242084',
#      'value_name': 'No',
#      'values': [{'source': 4709975701260268,
#        'id': '242084',
#        'name': 'No',
#        'struct': None}],
#      'attribute_group_name': 'Comodidades y amenities',
#      'source': 4709975701260268,
#      'value_type': 'boolean'},
#     {'source': 4709975701260268,
#      'value_type': 'number',
#      'id': 'BEDROOMS',
#      'value_id': None,
#      'values': [{'name': '2',
#        'struct': None,
#        'source': 4709975701260268,
#        'id': None}],
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'name': 'Dormitorios',
#      'value_name': '2',
#      'value_struct': None},
#     {'value_name': '94 m²',
#      'value_struct': {'number': 94, 'unit': 'm²'},
#      'values': [{'id': None,
#        'name': '94 m²',
#        'struct': {'number': 94, 'unit': 'm²'},
#        'source': 4709975701260268}],
#      'value_type': 'number_unit',
#      'attribute_group_name': 'Ficha técnica',
#      'source': 4709975701260268,
#      'id': 'COVERED_AREA',
#      'name': 'Superficie cubierta',
#      'value_id': None,
#      'attribute_group_id': 'FIND'},
#     {'attribute_group_name': 'Ficha técnica',
#      'source': 4709975701260268,
#      'value_type': 'number',
#      'id': 'FULL_BATHROOMS',
#      'value_struct': None,
#      'attribute_group_id': 'FIND',
#      'values': [{'name': '2',
#        'struct': None,
#        'source': 4709975701260268,
#        'id': None}],
#      'name': 'Baños',
#      'value_id': None,
#      'value_name': '2'},
#     {'value_name': '3',
#      'value_struct': None,
#      'values': [{'source': 4709975701260268,
#        'id': None,
#        'name': '3',
#        'struct': None}],
#      'attribute_group_id': 'FIND',
#      'source': 4709975701260268,
#      'id': 'ROOMS',
#      'name': 'Ambientes',
#      'value_id': None,
#      'value_type': 'number',
#      'attribute_group_name': 'Ficha técnica'},
#     {'value_type': 'number_unit',
#      'value_name': '94 m²',
#      'values': [{'id': None,
#        'name': '94 m²',
#        'struct': {'number': 94, 'unit': 'm²'},
#        'source': 4709975701260268}],
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'source': 4709975701260268,
#      'id': 'TOTAL_AREA',
#      'name': 'Superficie total',
#      'value_id': None,
#      'value_struct': {'number': 94, 'unit': 'm²'}},
#     {'id': 'OPERATION',
#      'name': 'Operación',
#      'value_struct': None,
#      'source': 1,
#      'value_type': 'list',
#      'value_id': '242075',
#      'value_name': 'Venta',
#      'values': [{'id': '242075',
#        'name': 'Venta',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'MAIN',
#      'attribute_group_name': 'Principales'},
#     {'value_struct': None,
#      'attribute_group_id': 'MAIN',
#      'source': 1,
#      'value_type': 'list',
#      'value_id': '242062',
#      'name': 'Inmueble',
#      'value_name': 'Departamento',
#      'values': [{'id': '242062',
#        'name': 'Departamento',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Principales',
#      'id': 'PROPERTY_TYPE'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_name': 'Usado',
#      'values': [{'id': '2230581',
#        'name': 'Usado',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'value_type': 'list',
#      'value_id': '2230581',
#      'value_struct': None,
#      'attribute_group_name': 'Otros',
#      'source': 1},
#     {'id': 'WITH_VIRTUAL_TOUR',
#      'value_id': '242084',
#      'value_name': 'No',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 942334329061206}],
#      'attribute_group_id': 'OTHERS',
#      'value_type': 'boolean',
#      'name': 'Tour virtual',
#      'attribute_group_name': 'Otros',
#      'source': 942334329061206}],
#    'original_price': None,
#    'category_id': 'MLA401686',
#    'official_store_id': None,
#    'domain_id': 'MLA-INDIVIDUAL_APARTMENTS_FOR_SALE',
#    'catalog_product_id': None,
#    'tags': ['good_quality_picture', 'good_quality_thumbnail'],
#    'order_backend': 1,
#    'use_thumbnail_id': True,
#    'offer_score': None,
#    'offer_share': None,
#    'match_score': None,
#    'winner_item_id': None,
#    'melicoin': None,
#    'discounts': None,
#    'inventory_id': None},
#   {'id': 'MLA1214575464',
#    'site_id': 'MLA',
#    'title': 'Monoambiente  - Ramos Mejia',
#    'seller': {'id': 167144578,
#     'permalink': 'http://perfil.mercadolibre.com.ar/INMOBILIARIA+GILGES',
#     'registration_date': '2014-09-20T08:41:24.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': True,
#     'tags': ['real_estate_agency',
#      'brand',
#      'nsm_high',
#      'credits_profile',
#      'credits_priority_3',
#      'messages_as_seller'],
#     'seller_reputation': {'power_seller_status': None,
#      'level_id': None,
#      'metrics': {'cancellations': {'period': '365 days',
#        'rate': 0,
#        'value': 0},
#       'claims': {'period': '365 days', 'rate': 0, 'value': 0},
#       'delayed_handling_time': {'period': '365 days', 'rate': 0, 'value': 0},
#       'sales': {'period': '365 days', 'completed': 0}},
#      'transactions': {'canceled': 0,
#       'period': 'historic',
#       'total': 0,
#       'ratings': {'negative': 0, 'neutral': 0, 'positive': 0},
#       'completed': 0}}},
#    'price': 35000,
#    'prices': {'id': 'MLA1214575464',
#     'prices': [{'id': '1',
#       'type': 'standard',
#       'amount': 35000,
#       'regular_amount': None,
#       'currency_id': 'ARS',
#       'last_updated': '2022-10-26T20:33:32Z',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {}}],
#     'presentation': {'display_currency': 'ARS'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'ARS',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'classified',
#    'listing_type_id': 'gold_premium',
#    'stop_time': '2023-10-26T04:00:00.000Z',
#    'condition': 'used',
#    'permalink': 'https://departamento.mercadolibre.com.ar/MLA-1214575464-monoambiente-ramos-mejia-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_684034-MLA52149777051_102022-I.jpg',
#    'thumbnail_id': '684034-MLA52149777051_102022',
#    'accepts_mercadopago': False,
#    'installments': None,
#    'address': {'state_id': 'TUxBUEdSQWVmNTVm',
#     'state_name': 'Bs.As. G.B.A. Oeste',
#     'city_id': 'TUxBQ0xBTWF0YW56',
#     'city_name': 'La Matanza',
#     'area_code': '',
#     'phone1': ''},
#    'promotions': None,
#    'shipping': {'free_shipping': False,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': 'not_specified',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#     'city': {'id': None, 'name': 'Ramos Mejía'},
#     'latitude': '',
#     'longitude': ''},
#    'seller_contact': {'contact': 'Gilges Inmobiliaria',
#     'other_info': '',
#     'area_code': '',
#     'phone': '',
#     'area_code2': '',
#     'phone2': '',
#     'email': '',
#     'webpage': ''},
#    'location': {'address_line': 'Pueyrredon al 400',
#     'zip_code': '',
#     'subneighborhood': None,
#     'neighborhood': {'id': 'TUxBQlJBTTE3Mzla', 'name': 'Ramos Mejía'},
#     'city': {'id': 'TUxBQ0xBTWF0YW56', 'name': 'La Matanza'},
#     'state': {'id': 'TUxBUEdSQWVmNTVm', 'name': 'Bs.As. G.B.A. Oeste'},
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'latitude': -34.643703,
#     'longitude': -58.560165},
#    'attributes': [{'id': 'HAS_TELEPHONE_LINE',
#      'name': 'Línea telefónica',
#      'values': [{'name': 'No',
#        'struct': None,
#        'source': 4709975701260268,
#        'id': '242084'}],
#      'attribute_group_id': 'CARACTERISTICAS',
#      'attribute_group_name': 'Características adicionales',
#      'value_id': '242084',
#      'value_name': 'No',
#      'value_struct': None,
#      'source': 4709975701260268,
#      'value_type': 'boolean'},
#     {'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 4709975701260268}],
#      'attribute_group_id': 'COMOYAMEN',
#      'attribute_group_name': 'Comodidades y amenities',
#      'source': 4709975701260268,
#      'value_type': 'boolean',
#      'value_id': '242084',
#      'value_struct': None,
#      'value_name': 'No',
#      'id': 'HAS_AIR_CONDITIONING',
#      'name': 'Aire acondicionado'},
#     {'value_name': '0',
#      'value_struct': None,
#      'id': 'BEDROOMS',
#      'value_id': None,
#      'values': [{'name': '0',
#        'struct': None,
#        'source': 4709975701260268,
#        'id': None}],
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'source': 4709975701260268,
#      'value_type': 'number',
#      'name': 'Dormitorios'},
#     {'attribute_group_id': 'FIND',
#      'source': 4709975701260268,
#      'value_id': None,
#      'name': 'Superficie cubierta',
#      'value_name': '21 m²',
#      'value_struct': {'number': 21, 'unit': 'm²'},
#      'values': [{'source': 4709975701260268,
#        'id': None,
#        'name': '21 m²',
#        'struct': {'unit': 'm²', 'number': 21}}],
#      'attribute_group_name': 'Ficha técnica',
#      'value_type': 'number_unit',
#      'id': 'COVERED_AREA'},
#     {'value_name': '1',
#      'attribute_group_name': 'Ficha técnica',
#      'value_type': 'number',
#      'id': 'FULL_BATHROOMS',
#      'value_id': None,
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 4709975701260268}],
#      'attribute_group_id': 'FIND',
#      'source': 4709975701260268,
#      'name': 'Baños',
#      'value_struct': None},
#     {'id': 'ROOMS',
#      'name': 'Ambientes',
#      'value_id': None,
#      'value_name': '1',
#      'attribute_group_name': 'Ficha técnica',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 4709975701260268}],
#      'attribute_group_id': 'FIND',
#      'source': 4709975701260268,
#      'value_type': 'number'},
#     {'name': 'Superficie total',
#      'value_id': None,
#      'value_name': '21 m²',
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'source': 4709975701260268,
#      'value_type': 'number_unit',
#      'id': 'TOTAL_AREA',
#      'value_struct': {'number': 21, 'unit': 'm²'},
#      'values': [{'id': None,
#        'name': '21 m²',
#        'struct': {'number': 21, 'unit': 'm²'},
#        'source': 4709975701260268}]},
#     {'attribute_group_id': 'MAIN',
#      'values': [{'id': '242073',
#        'name': 'Alquiler',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Principales',
#      'source': 1,
#      'id': 'OPERATION',
#      'name': 'Operación',
#      'value_id': '242073',
#      'value_name': 'Alquiler',
#      'value_struct': None,
#      'value_type': 'list'},
#     {'value_name': 'Departamento',
#      'value_struct': None,
#      'values': [{'id': '242062',
#        'name': 'Departamento',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'MAIN',
#      'source': 1,
#      'id': 'PROPERTY_TYPE',
#      'name': 'Inmueble',
#      'value_id': '242062',
#      'attribute_group_name': 'Principales',
#      'value_type': 'list'},
#     {'attribute_group_id': 'OTHERS',
#      'value_type': 'list',
#      'value_struct': None,
#      'values': [{'id': '2230581',
#        'name': 'Usado',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Otros',
#      'source': 1,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230581',
#      'value_name': 'Usado'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 942334329061206,
#      'value_type': 'boolean',
#      'id': 'WITH_VIRTUAL_TOUR',
#      'value_id': '242084',
#      'values': [{'source': 942334329061206,
#        'id': '242084',
#        'name': 'No',
#        'struct': None}],
#      'name': 'Tour virtual',
#      'value_name': 'No',
#      'value_struct': None}],
#    'original_price': None,
#    'category_id': 'MLA1473',
#    'official_store_id': 3013,
#    'domain_id': 'MLA-APARTMENTS_FOR_RENT',
#    'catalog_product_id': None,
#    'tags': ['good_quality_picture', 'good_quality_thumbnail'],
#    'order_backend': 2,
#    'use_thumbnail_id': True,
#    'offer_score': None,
#    'offer_share': None,
#    'match_score': None,
#    'winner_item_id': None,
#    'melicoin': None,
#    'discounts': None,
#    'inventory_id': None},
#   {'id': 'MLA1211866303',
#    'site_id': 'MLA',
#    'title': 'Departamento 2 Ambientes.se Entrega Todo Pintado.( Dueño Directo Sin Comisión )',
#    'seller': {'id': 7931154,
#     'permalink': 'http://perfil.mercadolibre.com.ar/MENFA2011',
#     'registration_date': '2010-10-04T18:53:02.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'credits_profile', 'messages_as_seller'],
#     'seller_reputation': {'power_seller_status': None,
#      'level_id': None,
#      'metrics': {'cancellations': {'period': '365 days',
#        'rate': 0,
#        'value': 1},
#       'claims': {'period': '365 days', 'rate': 0, 'value': 0},
#       'delayed_handling_time': {'period': '365 days', 'rate': 0, 'value': 0},
#       'sales': {'period': '365 days', 'completed': 0}},
#      'transactions': {'canceled': 1,
#       'period': 'historic',
#       'total': 1,
#       'ratings': {'negative': 0, 'neutral': 1, 'positive': 0},
#       'completed': 0}}},
#    'price': 42000,
#    'prices': {'id': 'MLA1211866303',
#     'prices': [{'id': '1',
#       'type': 'standard',
#       'amount': 42000,
#       'regular_amount': None,
#       'currency_id': 'ARS',
#       'last_updated': '2022-10-25T05:33:03Z',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {}}],
#     'presentation': {'display_currency': 'ARS'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'ARS',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'classified',
#    'listing_type_id': 'gold_premium',
#    'stop_time': '2022-12-24T04:00:15.000Z',
#    'condition': 'not_specified',
#    'permalink': 'https://departamento.mercadolibre.com.ar/MLA-1211866303-departamento-2-ambientesse-entrega-todo-pintado-dueno-directo-sin-comision--_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_678044-MLA52115744438_102022-I.jpg',
#    'thumbnail_id': '678044-MLA52115744438_102022',
#    'accepts_mercadopago': False,
#    'installments': None,
#    'address': {'state_id': 'TUxBUEdSQWU4ZDkz',
#     'state_name': 'Bs.As. G.B.A. Norte',
#     'city_id': 'TUxBQ1BJTGFyMTIz',
#     'city_name': 'Pilar',
#     'area_code': '',
#     'phone1': ''},
#    'promotions': None,
#    'shipping': {'free_shipping': False,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': None,
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#     'city': {'id': 'TUxBQ1BJTDQ3NDE', 'name': 'Pilar'},
#     'latitude': '',
#     'longitude': ''},
#    'seller_contact': {'contact': '',
#     'other_info': '',
#     'area_code': '',
#     'phone': '',
#     'area_code2': '',
#     'phone2': '',
#     'email': '',
#     'webpage': ''},
#    'location': {'address_line': 'las acacias  3051',
#     'zip_code': '',
#     'subneighborhood': None,
#     'neighborhood': {'id': 'TUxBQkxBTDU0MzFa', 'name': 'La Lonja'},
#     'city': {'id': 'TUxBQ1BJTGFyMTIz', 'name': 'Pilar'},
#     'state': {'id': 'TUxBUEdSQWU4ZDkz', 'name': 'Bs.As. G.B.A. Norte'},
#     'country': {'id': 'AR', 'name': 'Argentina'},
#     'latitude': -34.408703,
#     'longitude': -58.841675},
#    'attributes': [{'source': 1505,
#      'value_type': 'number',
#      'value_id': None,
#      'value_name': '1',
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'id': 'BEDROOMS',
#      'name': 'Dormitorios',
#      'value_struct': None,
#      'values': [{'id': None, 'name': '1', 'struct': None, 'source': 1505}]},
#     {'values': [{'id': None,
#        'name': '60 m²',
#        'struct': {'number': 60, 'unit': 'm²'},
#        'source': 1505}],
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'source': 1505,
#      'value_type': 'number_unit',
#      'value_name': '60 m²',
#      'value_struct': {'number': 60, 'unit': 'm²'},
#      'value_id': None,
#      'id': 'COVERED_AREA',
#      'name': 'Superficie cubierta'},
#     {'name': 'Baños',
#      'attribute_group_name': 'Ficha técnica',
#      'value_type': 'number',
#      'attribute_group_id': 'FIND',
#      'source': 1505,
#      'id': 'FULL_BATHROOMS',
#      'value_id': None,
#      'value_name': '1',
#      'value_struct': None,
#      'values': [{'name': '1', 'struct': None, 'source': 1505, 'id': None}]},
#     {'id': 'ROOMS',
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'source': 1505,
#      'value_type': 'number',
#      'name': 'Ambientes',
#      'value_id': None,
#      'value_name': '2',
#      'value_struct': None,
#      'values': [{'id': None, 'name': '2', 'struct': None, 'source': 1505}]},
#     {'value_name': '60 m²',
#      'value_struct': {'unit': 'm²', 'number': 60},
#      'source': 1505,
#      'value_type': 'number_unit',
#      'name': 'Superficie total',
#      'value_id': None,
#      'values': [{'id': None,
#        'name': '60 m²',
#        'struct': {'number': 60, 'unit': 'm²'},
#        'source': 1505}],
#      'attribute_group_id': 'FIND',
#      'attribute_group_name': 'Ficha técnica',
#      'id': 'TOTAL_AREA'},
#     {'name': 'Operación',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '242073',
#        'name': 'Alquiler',
#        'struct': None}],
#      'attribute_group_id': 'MAIN',
#      'value_type': 'list',
#      'id': 'OPERATION',
#      'value_id': '242073',
#      'value_name': 'Alquiler',
#      'attribute_group_name': 'Principales',
#      'source': 1},
#     {'value_struct': None,
#      'value_type': 'list',
#      'value_id': '242062',
#      'value_name': 'Departamento',
#      'values': [{'id': '242062',
#        'name': 'Departamento',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'MAIN',
#      'attribute_group_name': 'Principales',
#      'source': 1,
#      'id': 'PROPERTY_TYPE',
#      'name': 'Inmueble'},
#     {'value_id': '242084',
#      'attribute_group_name': 'Otros',
#      'attribute_group_id': 'OTHERS',
#      'source': 942334329061206,
#      'value_type': 'boolean',
#      'id': 'WITH_VIRTUAL_TOUR',
#      'name': 'Tour virtual',
#      'value_name': 'No',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 942334329061206}]}],
#    'original_price': None,
#    'category_id': 'MLA1473',
#    'official_store_id': None,
#    'domain_id': 'MLA-APARTMENTS_FOR_RENT',
#    'catalog_product_id': None,
#    'tags': ['good_quality_picture', 'good_quality_thumbnail'],
#    'order_backend': 3,
#    'use_thumbnail_id': True,
#    'offer_score': None,
#    'offer_share': None,
#    'match_score': None,
#    'winner_item_id': None,
#    'melicoin': None,
#    'discounts': None,
#    'inventory_id': None}],
#  'sort': {'id': 'relevance', 'name': 'Más relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor precio'},
#   {'id': 'price_desc', 'name': 'Mayor precio'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorías',
#    'type': 'text',
#    'values': [{'id': 'MLA1472',
#      'name': 'Departamentos',
#      'path_from_root': [{'id': 'MLA1459', 'name': 'Inmuebles'},
#       {'id': 'MLA1472', 'name': 'Departamentos'}]}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Tiendas oficiales',
#    'type': 'text',
#    'values': [{'id': 'all',
#      'name': 'Todas las tiendas oficiales',
#      'results': 32804},
#     {'id': '2973', 'name': 'Tormes Propiedades', 'results': 91},
#     {'id': '2636', 'name': 'Toribio Achaval', 'results': 797},
#     {'id': '2743', 'name': 'Sistema Coldwell Banker', 'results': 2381},
#     {'id': '2752', 'name': 'Okeefe', 'results': 246},
#     {'id': '2622', 'name': 'Estudio Yacoub', 'results': 2197},
#     {'id': '2684', 'name': 'Korn Propiedades', 'results': 916},
#     {'id': '2900', 'name': 'Oppel Inmobiliaria', 'results': 245},
#     {'id': '3035', 'name': 'DUIT Propiedades', 'results': 184},
#     {'id': '2015', 'name': 'Grupo VACCARO', 'results': 123},
#     {'id': '3013', 'name': 'Gilges Inmobiliaria', 'results': 62},
#     {'id': '2853', 'name': 'Deborah Sosa', 'results': 1},
#     {'id': '3022', 'name': 'BAU Propiedades', 'results': 1}]},
#   {'id': 'state',
#    'name': 'Ubicación',
#    'type': 'text',
#    'values': [{'id': 'TUxBUENBUGw3M2E1',
#      'name': 'Capital Federal',
#      'results': 90134},
#     {'id': 'TUxBUEdSQWVmNTVm',
#      'name': 'Bs.As. G.B.A. Oeste',
#      'results': 32942},
#     {'id': 'TUxBUEdSQWU4ZDkz',
#      'name': 'Bs.As. G.B.A. Norte',
#      'results': 32636},
#     {'id': 'TUxBUENPU2ExMmFkMw',
#      'name': 'Bs.As. Costa Atlántica',
#      'results': 32626},
#     {'id': 'TUxBUFNBTmU5Nzk2', 'name': 'Santa Fe', 'results': 30074},
#     {'id': 'TUxBUEdSQXJlMDNm', 'name': 'Bs.As. G.B.A. Sur', 'results': 29710},
#     {'id': 'TUxBUFVSVXllZDVl', 'name': 'Uruguay', 'results': 26596},
#     {'id': 'TUxBUENPUmFkZGIw', 'name': 'Córdoba', 'results': 12936},
#     {'id': 'TUxBUFpPTmFpbnRl',
#      'name': 'Buenos Aires Interior',
#      'results': 4392},
#     {'id': 'TUxBUE5FVW4xMzMzNQ', 'name': 'Neuquén', 'results': 1708},
#     {'id': 'TUxBUFLNT29iZmZm', 'name': 'Río Negro', 'results': 1708},
#     {'id': 'TUxBUFVTQWl1cXdlMg', 'name': 'USA', 'results': 1464},
#     {'id': 'TUxBUFRVQ244NmM3', 'name': 'Tucumán', 'results': 1098},
#     {'id': 'TUxBUE1FTmE5OWQ4', 'name': 'Mendoza', 'results': 854},
#     {'id': 'TUxBUEVOVHMzNTdm', 'name': 'Entre Ríos', 'results': 732},
#     {'id': 'TUxBUE1JU3MzNjIx', 'name': 'Misiones', 'results': 183},
#     {'id': 'TUxBUEJSQWwyMzA1', 'name': 'Brasil', 'results': 183},
#     {'id': 'TUxBUFNBTm5lYjU4', 'name': 'San Juan', 'results': 183},
#     {'id': 'TUxBUENPUnM5MjI0', 'name': 'Corrientes', 'results': 122},
#     {'id': 'TUxBUFNBTGFjMTJi', 'name': 'Salta', 'results': 122},
#     {'id': 'TUxBUFNBTnM0ZTcz', 'name': 'San Luis', 'results': 61},
#     {'id': 'TUxBUFNBTno3ZmY5', 'name': 'Santa Cruz', 'results': 61}]},
#   {'id': 'price',
#    'name': 'Precio',
#    'type': 'range',
#    'values': [{'id': '*-1.0E7',
#      'name': 'Hasta $ 10.000.000',
#      'results': 89590},
#     {'id': '1.0E7-2.0E7',
#      'name': '$10.000.000 a $20.000.000',
#      'results': 107813},
#     {'id': '2.0E7-*', 'name': 'Más de $20.000.000', 'results': 103488}]},
#   {'id': 'power_seller',
#    'name': 'Filtro por calidad de vendedores',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Mejores vendedores', 'results': 123}]},
#   {'id': 'since',
#    'name': 'Filtro por fecha de comienzo',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Publicados hoy', 'results': 3295}]},
#   {'id': 'until',
#    'name': 'Filtro por fecha de finalización',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Finalizan hoy', 'results': 61}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicaciones con video',
#    'type': 'boolean',
#    'values': [{'id': 'yes',
#      'name': 'Publicaciones con video',
#      'results': 41083}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicaciones con imágenes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con fotos', 'results': 300464}]},
#   {'id': 'seller_type',
#    'name': 'Vendedor',
#    'type': 'text',
#    'values': [{'id': 'real_estate_agency',
#      'name': 'Inmobiliaria',
#      'results': 285941},
#     {'id': 'private_seller', 'name': 'Dueño directo', 'results': 14950}]},
#   {'id': 'BEDROOMS',
#    'name': 'Dormitorios',
#    'type': 'range',
#    'values': [{'id': '[0-0]', 'name': 'Monoambiente', 'results': 31270},
#     {'id': '[1-1]', 'name': '1 dormitorio', 'results': 131098},
#     {'id': '[2-2]', 'name': '2 dormitorios', 'results': 88677},
#     {'id': '[3-3]', 'name': '3 dormitorios', 'results': 39412},
#     {'id': '[4-*)', 'name': '4 dormitorios o más', 'results': 7670}]},
#   {'id': 'COVERED_AREA',
#    'name': 'Superficie cubierta',
#    'type': 'range',
#    'values': [{'id': '(*-40m²]',
#      'name': '40 m² cubiertos o menos',
#      'results': 85845},
#     {'id': '²-50m²]', 'name': '40 a 50 m² cubiertos', 'results': 73278},
#     {'id': '²-70m²]', 'name': '50 a 70 m² cubiertos', 'results': 78824},
#     {'id': '²-*)', 'name': '70 m² cubiertos o más', 'results': 91509}]},
#   {'id': 'FULL_BATHROOMS',
#    'name': 'Baños',
#    'type': 'range',
#    'values': [{'id': '[1-1]', 'name': '1 baño', 'results': 204022},
#     {'id': '[2-2]', 'name': '2 baños', 'results': 66316},
#     {'id': '[3-3]', 'name': '3 baños', 'results': 16579},
#     {'id': '[4-4]', 'name': '4 baños', 'results': 3953},
#     {'id': '[5-*)', 'name': '5 baños o más', 'results': 1593}]},
#   {'id': 'HAS_AIR_CONDITIONING',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con aire acondicionado',
#      'results': 63189}]},
#   {'id': 'HAS_GARDEN',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con jardín', 'results': 17818}]},
#   {'id': 'HAS_GRILL',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con parrilla', 'results': 44545}]},
#   {'id': 'HAS_GYM',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con gimnasio', 'results': 36639}]},
#   {'id': 'HAS_HALF_BATH',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con toilette', 'results': 50386}]},
#   {'id': 'HAS_MULTIPURPOSE_ROOM',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con salón de usos múltiples',
#      'results': 45843}]},
#   {'id': 'HAS_SWIMMING_POOL',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con pileta', 'results': 63838}]},
#   {'id': 'IS_FINANCEABLE',
#    'name': 'Financiable',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Es financiable', 'results': 9971}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 170451},
#     {'id': '2230284', 'name': 'Nuevo', 'results': 105374}]},
#   {'id': 'MAINTENANCE_FEE',
#    'name': 'Expensas',
#    'type': 'range',
#    'values': [{'id': '(*-3000ARS)',
#      'name': '3.000 ARS o menos',
#      'results': 119357},
#     {'id': '[3000ARS-5500ARS]', 'name': '3.000 a 5.500 ARS', 'results': 25960},
#     {'id': '[5500ARS-10000ARS]',
#      'name': '5.500 a 10.000 ARS',
#      'results': 24662},
#     {'id': '[10000ARS-*)', 'name': '10.000 ARS o más', 'results': 39471}]},
#   {'id': 'OPERATION',
#    'name': 'Operación',
#    'type': 'STRING',
#    'values': [{'id': '242075', 'name': 'Venta', 'results': 266444},
#     {'id': '242074', 'name': 'Alquiler temporal', 'results': 20414},
#     {'id': '242073', 'name': 'Alquiler', 'results': 9971}]},
#   {'id': 'OPERATION_SUBTYPE',
#    'name': 'Modalidad',
#    'type': 'STRING',
#    'values': [{'id': '244562',
#      'name': 'Propiedades individuales',
#      'results': 265559},
#     {'id': '245034', 'name': 'Emprendimientos', 'results': 1475}]},
#   {'id': 'PARKING_LOTS',
#    'name': 'Cocheras',
#    'type': 'range',
#    'values': [{'id': '[0-0]', 'name': 'No tiene cocheras', 'results': 194582},
#     {'id': '[1-1]', 'name': '1 cochera', 'results': 89975},
#     {'id': '[2-2]', 'name': '2 cocheras', 'results': 11033},
#     {'id': '[3-3]', 'name': '3 cocheras', 'results': 826},
#     {'id': '[4-*)', 'name': '4 cocheras o más', 'results': 944}]},
#   {'id': 'PROFESSIONAL_USE_ALLOWED',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Apto profesional', 'results': 29854}]},
#   {'id': 'PROPERTY_AGE',
#    'name': 'Antigüedad',
#    'type': 'range',
#    'values': [{'id': '[0años-0años]', 'name': 'A estrenar', 'results': 93692},
#     {'id': '[1años-6años]', 'name': '1 a 6 años', 'results': 33925},
#     {'id': '[6años-20años]', 'name': '6 a 20 años', 'results': 36757},
#     {'id': '[20años-50años]', 'name': '20 a 50 años', 'results': 40828},
#     {'id': '[50años-*)', 'name': '50 años o más', 'results': 9499}]},
#   {'id': 'PROPERTY_TYPE',
#    'name': 'Inmueble',
#    'type': 'STRING',
#    'values': [{'id': '242062', 'name': 'Departamentos', 'results': 296829}]},
#   {'id': 'ROOMS',
#    'name': 'Ambientes',
#    'type': 'range',
#    'values': [{'id': '[1-1]', 'name': '1 ambiente', 'results': 43896},
#     {'id': '[2-2]', 'name': '2 ambientes', 'results': 112454},
#     {'id': '[3-3]', 'name': '3 ambientes', 'results': 82600},
#     {'id': '[4-*)', 'name': '4 ambientes o más', 'results': 51448}]},
#   {'id': 'SUITABLE_FOR_MORTGAGE_LOAN',
#    'name': 'Apto crédito',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Es apto crédito', 'results': 38114}]},
#   {'id': 'TOTAL_AREA',
#    'name': 'Superficie total',
#    'type': 'range',
#    'values': [{'id': '(*-45m²]',
#      'name': '45 m² totales o menos',
#      'results': 87792},
#     {'id': '²-60m²]', 'name': '45 a 60 m² totales', 'results': 76346},
#     {'id': '²-85m²]', 'name': '60 a 85 m² totales', 'results': 69974},
#     {'id': '²-*)', 'name': '85 m² totales o más', 'results': 77113}]},
#   {'id': 'WITH_VIRTUAL_TOUR',
#    'name': 'Multimedia',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Tour virtual', 'results': 1298}]}]}

# %%
#, meta=['id', 'site_id', 'title', 'seller', 'price', 'prices', 'sale_price', 'currency_id', 'available_quantity', 'sold_quantity', 'buying_mode', 'listing_type_id', 'stop_time', 'condition', 'permalink', 'thumbnail', 'thumbnail_id', 'accepts_mercadopago', 'installments', 'address', 'promotions', 'shipping', 'seller_address', 'seller_contact', 'location', 'attributes', 'original_price', 'category_id', 'official_store_id', 'domain_id', 'catalog_product_id', 'tags', 'order_backend', 'use_thumbnail_id', 'offer_score', 'offer_share', 'match_score', 'winner_item_id', 'melicoin', 'discounts', 'inventory_id'])
#pd.json_normalize(data, "prices", ["results"][0])
# ["id", "type", "amount", "regular_amount", "currency_id", "last_updated", "conditions", "exchange_rate_context", "metadata"]
serie = pd.json_normalize(data["results"], sep="-",)['prices-prices'].keys()
pd.json_normalize(serie)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
serie
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
pd.json_normalize(data, "filters", )#, [, ["id", "type", "amount", "regular_amount", "currency_id", "last_updated", "conditions"]])#, errors='ignore')
# Out:
#          id        name  type  \
# 0  category  Categorías  text
#
#                                               values
# 0  [{'id': 'MLA1472', 'name': 'Departamentos', 'p...

# %%
df["prices.prices"]
# Out:
# 0    [{'id': '1', 'type': 'standard', 'amount': 185...
# 1    [{'id': '1', 'type': 'standard', 'amount': 350...
# 2    [{'id': '1', 'type': 'standard', 'amount': 420...
# Name: prices.prices, dtype: object

# %%
for offset in range(0,paginators):
    url = self.ml_url + self.objeto.mercadolibre_id + '&_PublishedToday_YES&limit=50&offset=' + str(offset*50)
    jsdata = self.request_get(url)
    if(jsdata is not None): self.items = self.items + jsdata['results']
self.adapt()

# %%
json.dumps(data['results'][0]['attributes'])

# %%
import requests
import json
import pandas as pd

url = 'https://api.mercadolibre.com/items/MLA1216652308'
r = requests.get(url)
data = json.loads(r.content)

pd.json_normalize(data, 'attributes')[['name', 'value_name']]
# Out:
#                            name    value_name
# 0                        Balcón            Sí
# 1           Dormitorio en suite            Sí
# 2                      Placards            Sí
# 3                       Comedor            Sí
# 4                        Cocina            Sí
# 5                        Living            Sí
# 6                       Terraza            Sí
# 7                Agua corriente            Sí
# 8              Línea telefónica            Sí
# 9              Apto profesional            Sí
# 10           Aire acondicionado            Sí
# 11                      Laundry            Sí
# 12                    Recepción            Sí
# 13                     Gimnasio            Sí
# 14                     Ascensor            Sí
# 15                       Pileta            Sí
# 16       Departamentos por piso             4
# 17                  Dormitorios             1
# 18          Superficie cubierta         35 m²
# 19                  Disposición        Frente
# 20                  Orientación         Norte
# 21            Cantidad de pisos             8
# 22                        Baños             1
# 23                     Expensas     20000 ARS
# 24                     Cocheras             0
# 25                   Antigüedad        8 años
# 26                    Ambientes             1
# 27             Superficie total         38 m²
# 28  Número de piso de la unidad             4
# 29                      Bodegas             0
# 30                    Operación      Alquiler
# 31                     Inmueble  Departamento
# 32      Número del departamento             C
# 33           Condición del ítem         Usado
# 34                 Tour virtual            No

# %%
atrs = pd.json_normalize(data, 'attributes')[['name', 'value_name']].T
atrs = atrs.rename(columns=atrs.iloc[0]).drop(atrs.index[0])
atrs
# Out:
#            Balcón Dormitorio en suite Placards Comedor Cocina Living Terraza  \
# value_name     Sí                  Sí       Sí      Sí     Sí     Sí      Sí
#
#            Agua corriente Línea telefónica Apto profesional  ... Antigüedad  \
# value_name             Sí               Sí               Sí  ...     8 años
#
#            Ambientes Superficie total Número de piso de la unidad Bodegas  \
# value_name         1            38 m²                           4       0
#
#            Operación      Inmueble Número del departamento Condición del ítem  \
# value_name  Alquiler  Departamento                       C              Usado
#
#            Tour virtual
# value_name           No
#
# [1 rows x 35 columns]

# %%
df = pd.json_normalize(data)
df
# Out:
#               id site_id                                              title  \
# 0  MLA1216652308     MLA  Excepcional Monoambiente De Categoría Próximo ...
#
#   subtitle  seller_id category_id official_store_id  price  base_price  \
# 0     None   29097609     MLA1473              None  79000       79000
#
#   original_price  ...                 location.address_line  \
# 0           None  ...  Bulnes 2710, Buenos Aires, Argentina
#
#    location.zip_code  location.neighborhood.id  location.neighborhood.name  \
# 0                             TUxBQlBBTDI1MTVa                     Palermo
#
#      location.city.id location.city.name location.state.id  \
# 0  TUxBQ0NBUGZlZG1sYQ    Capital Federal  TUxBUENBUGw3M2E1
#
#   location.state.name location.country.id location.country.name
# 0     Capital Federal                  AR             Argentina
#
# [1 rows x 91 columns]

# %%
df.loc[:,df.columns.str.contains('time')]
# Out:
#                  start_time                 stop_time
# 0  2022-10-28T17:59:10.000Z  2022-12-27T04:00:59.000Z

# %%
df.loc[:,df.columns.str.startswith('location')]
# Out:
#                   location.address_line location.zip_code  \
# 0  Bulnes 2710, Buenos Aires, Argentina
#
#   location.neighborhood.id location.neighborhood.name    location.city.id  \
# 0         TUxBQlBBTDI1MTVa                    Palermo  TUxBQ0NBUGZlZG1sYQ
#
#   location.city.name location.state.id location.state.name  \
# 0    Capital Federal  TUxBUENBUGw3M2E1     Capital Federal
#
#   location.country.id location.country.name
# 0                  AR             Argentina

# %%
df.loc[:, df.columns.str.startswith('seller'),]
# Out:
# Index(['seller_id', 'seller_address.city.id', 'seller_address.city.name',
#        'seller_address.state.id', 'seller_address.state.name',
#        'seller_address.country.id', 'seller_address.country.name',
#        'seller_address.search_location.neighborhood.id',
#        'seller_address.search_location.neighborhood.name',
#        'seller_address.search_location.city.id',
#        'seller_address.search_location.city.name',
#        'seller_address.search_location.state.id',
#        'seller_address.search_location.state.name', 'seller_address.id',
#        'seller_contact.contact', 'seller_contact.other_info',
#        'seller_contact.country_code', 'seller_contact.area_code',
#        'seller_contact.phone', 'seller_contact.country_code2',
#        'seller_contact.area_code2', 'seller_contact.phone2',
#        'seller_contact.email', 'seller_contact.webpage'],
#       dtype='object')

# %%
df.drop(columns=['site_id', 'site_id', 'location.neighborhood.id', 'location.city.id', 'location.state.id', 'location.country.id'], inplace=True)
df
# Out:
#               id                                              title subtitle  \
# 0  MLA1216652308  Excepcional Monoambiente De Categoría Próximo ...     None
#
#    seller_id category_id official_store_id  price  base_price original_price  \
# 0   29097609     MLA1473              None  79000       79000           None
#
#   currency_id  ...  seller_contact.area_code2  seller_contact.phone2  \
# 0         ARS  ...
#
#    seller_contact.email seller_contact.webpage  \
# 0
#
#                   location.address_line location.zip_code  \
# 0  Bulnes 2710, Buenos Aires, Argentina
#
#   location.neighborhood.name location.city.name location.state.name  \
# 0                    Palermo    Capital Federal     Capital Federal
#
#   location.country.name
# 0             Argentina
#
# [1 rows x 86 columns]

# %%
df.drop(columns=['seller_contact.area_code2', 'seller_contact.phone2', 'seller_contact.email', 'seller_contact.webpage'], inplace=True)
df
# Out:
#               id                                              title subtitle  \
# 0  MLA1216652308  Excepcional Monoambiente De Categoría Próximo ...     None
#
#    seller_id category_id official_store_id  price  base_price original_price  \
# 0   29097609     MLA1473              None  79000       79000           None
#
#   currency_id  ...  seller_contact.country_code  seller_contact.area_code  \
# 0         ARS  ...
#
#    seller_contact.phone seller_contact.country_code2  \
# 0
#
#                   location.address_line location.zip_code  \
# 0  Bulnes 2710, Buenos Aires, Argentina
#
#   location.neighborhood.name location.city.name location.state.name  \
# 0                    Palermo    Capital Federal     Capital Federal
#
#   location.country.name
# 0             Argentina
#
# [1 rows x 82 columns]

# %%
#list(df.filter(regex='seller_contact'))
df.loc[:,df.columns.str.startswith('seller')]
# Out:
#    seller_id seller_address.city.id seller_address.city.name  \
# 0   29097609       TUxBQlBBTDI1MTVa                  Palermo
#
#   seller_address.state.id seller_address.state.name seller_address.country.id  \
# 0                    AR-C           Capital Federal                        AR
#
#   seller_address.country.name seller_address.search_location.neighborhood.id  \
# 0                   Argentina                               TUxBQlBBTDI1MTVa
#
#   seller_address.search_location.neighborhood.name  \
# 0                                          Palermo
#
#   seller_address.search_location.city.id  ... seller_contact.contact  \
# 0                     TUxBQ0NBUGZlZG1sYQ  ...
#
#   seller_contact.other_info seller_contact.country_code  \
# 0
#
#    seller_contact.area_code seller_contact.phone seller_contact.country_code2  \
# 0
#
#   seller_contact.area_code2 seller_contact.phone2 seller_contact.email  \
# 0
#
#   seller_contact.webpage
# 0
#
# [1 rows x 24 columns]

# %%
df = df.loc[:,~df.columns.str.startswith('seller')]
df
# Out:
#               id                                              title subtitle  \
# 0  MLA1216652308  Excepcional Monoambiente De Categoría Próximo ...     None
#
#   category_id official_store_id  price  base_price original_price currency_id  \
# 0     MLA1473              None  79000       79000           None         ARS
#
#    initial_quantity  ...  shipping.local_pick_up  shipping.free_shipping  \
# 0                 1  ...                   False                   False
#
#   shipping.logistic_type shipping.store_pick_up  \
# 0                   None                  False
#
#                   location.address_line location.zip_code  \
# 0  Bulnes 2710, Buenos Aires, Argentina
#
#   location.neighborhood.name location.city.name location.state.name  \
# 0                    Palermo    Capital Federal     Capital Federal
#
#   location.country.name
# 0             Argentina
#
# [1 rows x 62 columns]

# %%
df.loc[:, df.columns.str.startswith('shipping')]
# Out:
#    shipping.mode shipping.methods shipping.tags shipping.dimensions  \
# 0  not_specified               []            []                None
#
#    shipping.local_pick_up  shipping.free_shipping shipping.logistic_type  \
# 0                   False                   False                   None
#
#    shipping.store_pick_up
# 0                   False

# %%
df = df.loc[:, ~df.columns.str.startswith('shipping')]
df
# Out:
#               id                                              title subtitle  \
# 0  MLA1216652308  Excepcional Monoambiente De Categoría Próximo ...     None
#
#   category_id official_store_id  price  base_price original_price currency_id  \
# 0     MLA1473              None  79000       79000           None         ARS
#
#    initial_quantity  ...              last_updated  health catalog_listing  \
# 0                 1  ...  2022-11-03T11:43:32.000Z     0.6           False
#
#         channels                 location.address_line location.zip_code  \
# 0  [marketplace]  Bulnes 2710, Buenos Aires, Argentina
#
#   location.neighborhood.name location.city.name location.state.name  \
# 0                    Palermo    Capital Federal     Capital Federal
#
#   location.country.name
# 0             Argentina
#
# [1 rows x 54 columns]

# %%
df.columns.str.startswith('attributes')
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])
